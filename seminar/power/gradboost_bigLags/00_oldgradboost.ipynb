# %% [markdown]
# Applying Gradient Boosting Models to forecast Power Demand.
#
# The aim of this script is to obtain a strong XGBOOST model, based on data prior to the beginning of the challenge.
# The resulting model will then be retrained/tuned with newer data as the challenge progresses.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import  mean_pinball_loss, d2_pinball_score, make_scorer

import requests
from datetime import datetime, date, timedelta
from tqdm import tqdm

import ephem

# %%
def get_energy_data():

    # get all available time stamps
    stampsurl = "https://www.smard.de/app/chart_data/410/DE/index_quarterhour.json"
    response = requests.get(stampsurl)
    #ignore first 4 years (don't need those in the baseline and speeds the code up a bit)
    timestamps = list(response.json()["timestamps"])[4*52:]

 
    col_names = ['date_time','Netzlast_Gesamt']
    energydata = pd.DataFrame(columns=col_names)
    
    # loop over all available timestamps
    for stamp in tqdm(timestamps):

        dataurl = "https://www.smard.de/app/chart_data/410/DE/410_DE_quarterhour_" + str(stamp) + ".json"
        response = requests.get(dataurl)
        rawdata = response.json()["series"]

        for i in range(len(rawdata)):

            rawdata[i][0] = datetime.fromtimestamp(int(str(rawdata[i][0])[:10])).strftime("%Y-%m-%d %H:%M:%S")

        energydata = pd.concat([energydata, pd.DataFrame(rawdata, columns=col_names)])

    energydata = energydata.dropna()
    energydata["date_time"] = pd.to_datetime(energydata.date_time)
    #set date_time as index
    energydata.set_index("date_time", inplace=True)
    #resample
    energydata = energydata.resample("1h", label = "left").sum()

    return energydata

# %%
# Quantiles
alpha = np.array([.025, .25, .5, .75, .975])

# Create dataframe
df_raw = get_energy_data()
df_raw = df_raw.rename(columns={"Netzlast_Gesamt": "gesamt"})
df_raw['gesamt'] = df_raw['gesamt'] / 1000
# Out:
#   0%|          | 0/275 [00:00<?, ?it/s]C:\Users\Bilal\AppData\Local\Temp\ipykernel_16896\2279548712.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   energydata = pd.concat([energydata, pd.DataFrame(rawdata, columns=col_names)])
# 100%|██████████| 275/275 [00:39<00:00,  6.92it/s]

# %%
# Set start-, forecast-, and end-date here
start_dt = '2018-12-24 00:00:00'        # Data Availability starts here
forecast_dt = '2024-03-13 23:00:00'     # Wednesday/Thursday midnight
forecast_date = '2024-03-13' 
end_dt = '2023-11-15 23:00:00'          # Sunday midnight

# %%
# filter data
df = df_raw.copy()
df = df.loc[(df.index >= start_dt) & (df.index <= end_dt)]
df
# Out:
#                        gesamt
# date_time
# 2018-12-24 00:00:00  42.02925
# 2018-12-24 01:00:00  39.61025
# 2018-12-24 02:00:00  39.13875
# 2018-12-24 03:00:00  39.42100
# 2018-12-24 04:00:00  40.74775
# ...                       ...
# 2023-11-15 19:00:00  65.46025
# 2023-11-15 20:00:00  62.23250
# 2023-11-15 21:00:00  59.06100
# 2023-11-15 22:00:00  55.62300
# 2023-11-15 23:00:00  52.01700
#
# [42912 rows x 1 columns]

# %%
holidays = pd.read_csv('C:\\Users\\Bilal\\Desktop\\ptsfc code\\seminar\\holidays.csv')
# holidays = np.array(holidays)
holidays.index = pd.to_datetime(holidays['x'])
holidays['date'] = holidays.index.date
holidays
# Out:
#                      x        date
# x
# 2018-01-01  2018-01-01  2018-01-01
# 2018-01-06  2018-01-06  2018-01-06
# 2018-03-30  2018-03-30  2018-03-30
# 2018-04-02  2018-04-02  2018-04-02
# 2018-05-01  2018-05-01  2018-05-01
# ...                ...         ...
# 2024-10-31  2024-10-31  2024-10-31
# 2024-11-01  2024-11-01  2024-11-01
# 2024-12-24  2024-12-24  2024-12-24
# 2024-12-25  2024-12-25  2024-12-25
# 2024-12-26  2024-12-26  2024-12-26
#
# [98 rows x 2 columns]

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    df['date'] = df.index.date # to join with daylight hours
    return df

# %%
def add_lags(df):                       # more lags? yesterday, last week, ...
    target_map = df['gesamt'].to_dict()
    df['lag1'] = (df.index - pd.Timedelta('4 days')).map(target_map)
    df['lag2'] = (df.index - pd.Timedelta('7 days')).map(target_map)
    df['lag3'] = (df.index - pd.Timedelta('364 days')).map(target_map) # 364, so we get this day last year on the same weekday
    # df['lag3'] = (df.index - pd.Timedelta('728 days')).map(target_map)
    # df['lag4'] = (df.index - pd.Timedelta('1092 days')).map(target_map)
    return df

# %%
# Define the observer location (latitude and longitude for Germany)
latitude = '51.1657'  # Latitude for Germany
longitude = '10.4515'  # Longitude for Germany

# Create an observer object
germany = ephem.Observer()
germany.lat = latitude
germany.lon = longitude

# Set the date for which you want to calculate sunrise time
start_date = df.index.min().date()      # begins at same day as df
end_date =  df.index.max().date()           # + timedelta(days=7)

# Dictionary to store daylight hours for each date
daylight_hours_dict = {}


current_date = start_date
while current_date <= end_date:
    # Set the observer's date
    germany.date = current_date

    # Compute the sunrise time
    sunrise = germany.next_rising(ephem.Sun())
    sunset = germany.next_setting(ephem.Sun())

    daylight_hours = (sunset - sunrise) * 24  # Convert from days to hours

    # Store daylight hours for current date in the dictionary
    daylight_hours_dict[current_date] = daylight_hours
    # Move to next dax
    current_date += timedelta(days=1)

# Print daylight hours for each date
for date, daylight_hours in daylight_hours_dict.items():
    print(f"{date}: Daylight: {daylight_hours:.2f} hours")
# Out:
# 2018-12-24: Daylight: 7.91 hours
# 2018-12-25: Daylight: 7.91 hours
# 2018-12-26: Daylight: 7.92 hours
# 2018-12-27: Daylight: 7.93 hours
# 2018-12-28: Daylight: 7.94 hours
# 2018-12-29: Daylight: 7.95 hours
# 2018-12-30: Daylight: 7.97 hours
# 2018-12-31: Daylight: 7.98 hours
# 2019-01-01: Daylight: 8.00 hours
# 2019-01-02: Daylight: 8.02 hours
# 2019-01-03: Daylight: 8.04 hours
# 2019-01-04: Daylight: 8.06 hours
# 2019-01-05: Daylight: 8.09 hours
# 2019-01-06: Daylight: 8.11 hours
# 2019-01-07: Daylight: 8.14 hours
# 2019-01-08: Daylight: 8.17 hours
# 2019-01-09: Daylight: 8.20 hours
# 2019-01-10: Daylight: 8.23 hours
# 2019-01-11: Daylight: 8.26 hours
# 2019-01-12: Daylight: 8.30 hours
# 2019-01-13: Daylight: 8.33 hours
# 2019-01-14: Daylight: 8.37 hours
# 2019-01-15: Daylight: 8.41 hours
# 2019-01-16: Daylight: 8.45 hours
# 2019-01-17: Daylight: 8.49 hours
# 2019-01-18: Daylight: 8.53 hours
# 2019-01-19: Daylight: 8.57 hours
# 2019-01-20: Daylight: 8.62 hours
# 2019-01-21: Daylight: 8.66 hours
# 2019-01-22: Daylight: 8.71 hours
# 2019-01-23: Daylight: 8.75 hours
# 2019-01-24: Daylight: 8.80 hours
# 2019-01-25: Daylight: 8.85 hours
# 2019-01-26: Daylight: 8.90 hours
# 2019-01-27: Daylight: 8.95 hours
# 2019-01-28: Daylight: 9.00 hours
# 2019-01-29: Daylight: 9.06 hours
# 2019-01-30: Daylight: 9.11 hours
# 2019-01-31: Daylight: 9.16 hours
# 2019-02-01: Daylight: 9.22 hours
# 2019-02-02: Daylight: 9.27 hours
# 2019-02-03: Daylight: 9.33 hours
# 2019-02-04: Daylight: 9.38 hours
# 2019-02-05: Daylight: 9.44 hours
# 2019-02-06: Daylight: 9.50 hours
# 2019-02-07: Daylight: 9.56 hours
# 2019-02-08: Daylight: 9.61 hours
# 2019-02-09: Daylight: 9.67 hours
# 2019-02-10: Daylight: 9.73 hours
# 2019-02-11: Daylight: 9.79 hours
# 2019-02-12: Daylight: 9.85 hours
# 2019-02-13: Daylight: 9.91 hours
# 2019-02-14: Daylight: 9.97 hours
# 2019-02-15: Daylight: 10.04 hours
# 2019-02-16: Daylight: 10.10 hours
# 2019-02-17: Daylight: 10.16 hours
# 2019-02-18: Daylight: 10.22 hours
# 2019-02-19: Daylight: 10.28 hours
# 2019-02-20: Daylight: 10.35 hours
# 2019-02-21: Daylight: 10.41 hours
# 2019-02-22: Daylight: 10.47 hours
# 2019-02-23: Daylight: 10.54 hours
# 2019-02-24: Daylight: 10.60 hours
# 2019-02-25: Daylight: 10.66 hours
# 2019-02-26: Daylight: 10.73 hours
# 2019-02-27: Daylight: 10.79 hours
# 2019-02-28: Daylight: 10.86 hours
# 2019-03-01: Daylight: 10.92 hours
# 2019-03-02: Daylight: 10.98 hours
# 2019-03-03: Daylight: 11.05 hours
# 2019-03-04: Daylight: 11.11 hours
# 2019-03-05: Daylight: 11.18 hours
# 2019-03-06: Daylight: 11.24 hours
# 2019-03-07: Daylight: 11.31 hours
# 2019-03-08: Daylight: 11.37 hours
# 2019-03-09: Daylight: 11.44 hours
# 2019-03-10: Daylight: 11.50 hours
# 2019-03-11: Daylight: 11.57 hours
# 2019-03-12: Daylight: 11.63 hours
# 2019-03-13: Daylight: 11.70 hours
# 2019-03-14: Daylight: 11.76 hours
# 2019-03-15: Daylight: 11.83 hours
# 2019-03-16: Daylight: 11.90 hours
# 2019-03-17: Daylight: 11.96 hours
# 2019-03-18: Daylight: 12.03 hours
# 2019-03-19: Daylight: 12.09 hours
# 2019-03-20: Daylight: 12.16 hours
# 2019-03-21: Daylight: 12.22 hours
# 2019-03-22: Daylight: 12.29 hours
# 2019-03-23: Daylight: 12.35 hours
# 2019-03-24: Daylight: 12.42 hours
# 2019-03-25: Daylight: 12.48 hours
# 2019-03-26: Daylight: 12.55 hours
# 2019-03-27: Daylight: 12.61 hours
# 2019-03-28: Daylight: 12.68 hours
# 2019-03-29: Daylight: 12.74 hours
# 2019-03-30: Daylight: 12.81 hours
# 2019-03-31: Daylight: 12.87 hours
# 2019-04-01: Daylight: 12.94 hours
# 2019-04-02: Daylight: 13.00 hours
# 2019-04-03: Daylight: 13.07 hours
# 2019-04-04: Daylight: 13.13 hours
# 2019-04-05: Daylight: 13.20 hours
# 2019-04-06: Daylight: 13.26 hours
# 2019-04-07: Daylight: 13.33 hours
# 2019-04-08: Daylight: 13.39 hours
# 2019-04-09: Daylight: 13.46 hours
# 2019-04-10: Daylight: 13.52 hours
# 2019-04-11: Daylight: 13.58 hours
# 2019-04-12: Daylight: 13.65 hours
# 2019-04-13: Daylight: 13.71 hours
# 2019-04-14: Daylight: 13.77 hours
# 2019-04-15: Daylight: 13.84 hours
# 2019-04-16: Daylight: 13.90 hours
# 2019-04-17: Daylight: 13.96 hours
# 2019-04-18: Daylight: 14.03 hours
# 2019-04-19: Daylight: 14.09 hours
# 2019-04-20: Daylight: 14.15 hours
# 2019-04-21: Daylight: 14.21 hours
# 2019-04-22: Daylight: 14.27 hours
# 2019-04-23: Daylight: 14.33 hours
# 2019-04-24: Daylight: 14.39 hours
# 2019-04-25: Daylight: 14.45 hours
# 2019-04-26: Daylight: 14.52 hours
# 2019-04-27: Daylight: 14.57 hours
# 2019-04-28: Daylight: 14.63 hours
# 2019-04-29: Daylight: 14.69 hours
# 2019-04-30: Daylight: 14.75 hours
# 2019-05-01: Daylight: 14.81 hours
# 2019-05-02: Daylight: 14.87 hours
# 2019-05-03: Daylight: 14.93 hours
# 2019-05-04: Daylight: 14.98 hours
# 2019-05-05: Daylight: 15.04 hours
# 2019-05-06: Daylight: 15.09 hours
# 2019-05-07: Daylight: 15.15 hours
# 2019-05-08: Daylight: 15.20 hours
# 2019-05-09: Daylight: 15.26 hours
# 2019-05-10: Daylight: 15.31 hours
# 2019-05-11: Daylight: 15.36 hours
# 2019-05-12: Daylight: 15.42 hours
# 2019-05-13: Daylight: 15.47 hours
# 2019-05-14: Daylight: 15.52 hours
# 2019-05-15: Daylight: 15.57 hours
# 2019-05-16: Daylight: 15.62 hours
# 2019-05-17: Daylight: 15.66 hours
# 2019-05-18: Daylight: 15.71 hours
# 2019-05-19: Daylight: 15.76 hours
# 2019-05-20: Daylight: 15.80 hours
# 2019-05-21: Daylight: 15.85 hours
# 2019-05-22: Daylight: 15.89 hours
# 2019-05-23: Daylight: 15.93 hours
# 2019-05-24: Daylight: 15.97 hours
# 2019-05-25: Daylight: 16.02 hours
# 2019-05-26: Daylight: 16.05 hours
# 2019-05-27: Daylight: 16.09 hours
# 2019-05-28: Daylight: 16.13 hours
# 2019-05-29: Daylight: 16.16 hours
# 2019-05-30: Daylight: 16.20 hours
# 2019-05-31: Daylight: 16.23 hours
# 2019-06-01: Daylight: 16.26 hours
# 2019-06-02: Daylight: 16.29 hours
# 2019-06-03: Daylight: 16.32 hours
# 2019-06-04: Daylight: 16.35 hours
# 2019-06-05: Daylight: 16.38 hours
# 2019-06-06: Daylight: 16.40 hours
# 2019-06-07: Daylight: 16.43 hours
# 2019-06-08: Daylight: 16.45 hours
# 2019-06-09: Daylight: 16.47 hours
# 2019-06-10: Daylight: 16.49 hours
# 2019-06-11: Daylight: 16.51 hours
# 2019-06-12: Daylight: 16.52 hours
# 2019-06-13: Daylight: 16.54 hours
# 2019-06-14: Daylight: 16.55 hours
# 2019-06-15: Daylight: 16.56 hours
# 2019-06-16: Daylight: 16.57 hours
# 2019-06-17: Daylight: 16.58 hours
# 2019-06-18: Daylight: 16.58 hours
# 2019-06-19: Daylight: 16.59 hours
# 2019-06-20: Daylight: 16.59 hours
# 2019-06-21: Daylight: 16.59 hours
# 2019-06-22: Daylight: 16.59 hours
# 2019-06-23: Daylight: 16.59 hours
# 2019-06-24: Daylight: 16.58 hours
# 2019-06-25: Daylight: 16.58 hours
# 2019-06-26: Daylight: 16.57 hours
# 2019-06-27: Daylight: 16.56 hours
# 2019-06-28: Daylight: 16.55 hours
# 2019-06-29: Daylight: 16.54 hours
# 2019-06-30: Daylight: 16.53 hours
# 2019-07-01: Daylight: 16.51 hours
# 2019-07-02: Daylight: 16.49 hours
# 2019-07-03: Daylight: 16.48 hours
# 2019-07-04: Daylight: 16.46 hours
# 2019-07-05: Daylight: 16.44 hours
# 2019-07-06: Daylight: 16.41 hours
# 2019-07-07: Daylight: 16.39 hours
# 2019-07-08: Daylight: 16.36 hours
# 2019-07-09: Daylight: 16.34 hours
# 2019-07-10: Daylight: 16.31 hours
# 2019-07-11: Daylight: 16.28 hours
# 2019-07-12: Daylight: 16.25 hours
# 2019-07-13: Daylight: 16.21 hours
# 2019-07-14: Daylight: 16.18 hours
# 2019-07-15: Daylight: 16.15 hours
# 2019-07-16: Daylight: 16.11 hours
# 2019-07-17: Daylight: 16.07 hours
# 2019-07-18: Daylight: 16.03 hours
# 2019-07-19: Daylight: 15.99 hours
# 2019-07-20: Daylight: 15.95 hours
# 2019-07-21: Daylight: 15.91 hours
# 2019-07-22: Daylight: 15.87 hours
# 2019-07-23: Daylight: 15.83 hours
# 2019-07-24: Daylight: 15.78 hours
# 2019-07-25: Daylight: 15.74 hours
# 2019-07-26: Daylight: 15.69 hours
# 2019-07-27: Daylight: 15.64 hours
# 2019-07-28: Daylight: 15.59 hours
# 2019-07-29: Daylight: 15.54 hours
# 2019-07-30: Daylight: 15.50 hours
# 2019-07-31: Daylight: 15.44 hours
# 2019-08-01: Daylight: 15.39 hours
# 2019-08-02: Daylight: 15.34 hours
# 2019-08-03: Daylight: 15.29 hours
# 2019-08-04: Daylight: 15.24 hours
# 2019-08-05: Daylight: 15.18 hours
# 2019-08-06: Daylight: 15.13 hours
# 2019-08-07: Daylight: 15.07 hours
# 2019-08-08: Daylight: 15.02 hours
# 2019-08-09: Daylight: 14.96 hours
# 2019-08-10: Daylight: 14.91 hours
# 2019-08-11: Daylight: 14.85 hours
# 2019-08-12: Daylight: 14.79 hours
# 2019-08-13: Daylight: 14.73 hours
# 2019-08-14: Daylight: 14.68 hours
# 2019-08-15: Daylight: 14.62 hours
# 2019-08-16: Daylight: 14.56 hours
# 2019-08-17: Daylight: 14.50 hours
# 2019-08-18: Daylight: 14.44 hours
# 2019-08-19: Daylight: 14.38 hours
# 2019-08-20: Daylight: 14.32 hours
# 2019-08-21: Daylight: 14.26 hours
# 2019-08-22: Daylight: 14.20 hours
# 2019-08-23: Daylight: 14.14 hours
# 2019-08-24: Daylight: 14.08 hours
# 2019-08-25: Daylight: 14.02 hours
# 2019-08-26: Daylight: 13.95 hours
# 2019-08-27: Daylight: 13.89 hours
# 2019-08-28: Daylight: 13.83 hours
# 2019-08-29: Daylight: 13.77 hours
# 2019-08-30: Daylight: 13.71 hours
# 2019-08-31: Daylight: 13.64 hours
# 2019-09-01: Daylight: 13.58 hours
# 2019-09-02: Daylight: 13.52 hours
# 2019-09-03: Daylight: 13.45 hours
# 2019-09-04: Daylight: 13.39 hours
# 2019-09-05: Daylight: 13.33 hours
# 2019-09-06: Daylight: 13.26 hours
# 2019-09-07: Daylight: 13.20 hours
# 2019-09-08: Daylight: 13.14 hours
# 2019-09-09: Daylight: 13.07 hours
# 2019-09-10: Daylight: 13.01 hours
# 2019-09-11: Daylight: 12.95 hours
# 2019-09-12: Daylight: 12.88 hours
# 2019-09-13: Daylight: 12.82 hours
# 2019-09-14: Daylight: 12.75 hours
# 2019-09-15: Daylight: 12.69 hours
# 2019-09-16: Daylight: 12.63 hours
# 2019-09-17: Daylight: 12.56 hours
# 2019-09-18: Daylight: 12.50 hours
# 2019-09-19: Daylight: 12.43 hours
# 2019-09-20: Daylight: 12.37 hours
# 2019-09-21: Daylight: 12.30 hours
# 2019-09-22: Daylight: 12.24 hours
# 2019-09-23: Daylight: 12.18 hours
# 2019-09-24: Daylight: 12.11 hours
# 2019-09-25: Daylight: 12.05 hours
# 2019-09-26: Daylight: 11.98 hours
# 2019-09-27: Daylight: 11.92 hours
# 2019-09-28: Daylight: 11.85 hours
# 2019-09-29: Daylight: 11.79 hours
# 2019-09-30: Daylight: 11.72 hours
# 2019-10-01: Daylight: 11.66 hours
# 2019-10-02: Daylight: 11.60 hours
# 2019-10-03: Daylight: 11.53 hours
# 2019-10-04: Daylight: 11.47 hours
# 2019-10-05: Daylight: 11.40 hours
# 2019-10-06: Daylight: 11.34 hours
# 2019-10-07: Daylight: 11.28 hours
# 2019-10-08: Daylight: 11.21 hours
# 2019-10-09: Daylight: 11.15 hours
# 2019-10-10: Daylight: 11.08 hours
# 2019-10-11: Daylight: 11.02 hours
# 2019-10-12: Daylight: 10.96 hours
# 2019-10-13: Daylight: 10.89 hours
# 2019-10-14: Daylight: 10.83 hours
# 2019-10-15: Daylight: 10.77 hours
# 2019-10-16: Daylight: 10.70 hours
# 2019-10-17: Daylight: 10.64 hours
# 2019-10-18: Daylight: 10.58 hours
# 2019-10-19: Daylight: 10.52 hours
# 2019-10-20: Daylight: 10.45 hours
# 2019-10-21: Daylight: 10.39 hours
# 2019-10-22: Daylight: 10.33 hours
# 2019-10-23: Daylight: 10.27 hours
# 2019-10-24: Daylight: 10.21 hours
# 2019-10-25: Daylight: 10.14 hours
# 2019-10-26: Daylight: 10.08 hours
# 2019-10-27: Daylight: 10.02 hours
# 2019-10-28: Daylight: 9.96 hours
# 2019-10-29: Daylight: 9.90 hours
# 2019-10-30: Daylight: 9.84 hours
# 2019-10-31: Daylight: 9.78 hours
# 2019-11-01: Daylight: 9.72 hours
# 2019-11-02: Daylight: 9.66 hours
# 2019-11-03: Daylight: 9.61 hours
# 2019-11-04: Daylight: 9.55 hours
# 2019-11-05: Daylight: 9.49 hours
# 2019-11-06: Daylight: 9.43 hours
# 2019-11-07: Daylight: 9.38 hours
# 2019-11-08: Daylight: 9.32 hours
# 2019-11-09: Daylight: 9.27 hours
# 2019-11-10: Daylight: 9.21 hours
# 2019-11-11: Daylight: 9.16 hours
# 2019-11-12: Daylight: 9.11 hours
# 2019-11-13: Daylight: 9.05 hours
# 2019-11-14: Daylight: 9.00 hours
# 2019-11-15: Daylight: 8.95 hours
# 2019-11-16: Daylight: 8.90 hours
# 2019-11-17: Daylight: 8.85 hours
# 2019-11-18: Daylight: 8.80 hours
# 2019-11-19: Daylight: 8.76 hours
# 2019-11-20: Daylight: 8.71 hours
# 2019-11-21: Daylight: 8.66 hours
# 2019-11-22: Daylight: 8.62 hours
# 2019-11-23: Daylight: 8.57 hours
# 2019-11-24: Daylight: 8.53 hours
# 2019-11-25: Daylight: 8.49 hours
# 2019-11-26: Daylight: 8.45 hours
# 2019-11-27: Daylight: 8.41 hours
# 2019-11-28: Daylight: 8.37 hours
# 2019-11-29: Daylight: 8.33 hours
# 2019-11-30: Daylight: 8.30 hours
# 2019-12-01: Daylight: 8.27 hours
# 2019-12-02: Daylight: 8.23 hours
# 2019-12-03: Daylight: 8.20 hours
# 2019-12-04: Daylight: 8.17 hours
# 2019-12-05: Daylight: 8.14 hours
# 2019-12-06: Daylight: 8.11 hours
# 2019-12-07: Daylight: 8.09 hours
# 2019-12-08: Daylight: 8.06 hours
# 2019-12-09: Daylight: 8.04 hours
# 2019-12-10: Daylight: 8.02 hours
# 2019-12-11: Daylight: 8.00 hours
# 2019-12-12: Daylight: 7.98 hours
# 2019-12-13: Daylight: 7.97 hours
# 2019-12-14: Daylight: 7.95 hours
# 2019-12-15: Daylight: 7.94 hours
# 2019-12-16: Daylight: 7.93 hours
# 2019-12-17: Daylight: 7.92 hours
# 2019-12-18: Daylight: 7.91 hours
# 2019-12-19: Daylight: 7.91 hours
# 2019-12-20: Daylight: 7.90 hours
# 2019-12-21: Daylight: 7.90 hours
# 2019-12-22: Daylight: 7.90 hours
# 2019-12-23: Daylight: 7.90 hours
# 2019-12-24: Daylight: 7.91 hours
# 2019-12-25: Daylight: 7.91 hours
# 2019-12-26: Daylight: 7.92 hours
# 2019-12-27: Daylight: 7.93 hours
# 2019-12-28: Daylight: 7.94 hours
# 2019-12-29: Daylight: 7.95 hours
# 2019-12-30: Daylight: 7.96 hours
# 2019-12-31: Daylight: 7.98 hours
# 2020-01-01: Daylight: 7.99 hours
# 2020-01-02: Daylight: 8.01 hours
# 2020-01-03: Daylight: 8.03 hours
# 2020-01-04: Daylight: 8.06 hours
# 2020-01-05: Daylight: 8.08 hours
# 2020-01-06: Daylight: 8.10 hours
# 2020-01-07: Daylight: 8.13 hours
# 2020-01-08: Daylight: 8.16 hours
# 2020-01-09: Daylight: 8.19 hours
# 2020-01-10: Daylight: 8.22 hours
# 2020-01-11: Daylight: 8.25 hours
# 2020-01-12: Daylight: 8.29 hours
# 2020-01-13: Daylight: 8.32 hours
# 2020-01-14: Daylight: 8.36 hours
# 2020-01-15: Daylight: 8.40 hours
# 2020-01-16: Daylight: 8.44 hours
# 2020-01-17: Daylight: 8.48 hours
# 2020-01-18: Daylight: 8.52 hours
# 2020-01-19: Daylight: 8.56 hours
# 2020-01-20: Daylight: 8.61 hours
# 2020-01-21: Daylight: 8.65 hours
# 2020-01-22: Daylight: 8.70 hours
# 2020-01-23: Daylight: 8.74 hours
# 2020-01-24: Daylight: 8.79 hours
# 2020-01-25: Daylight: 8.84 hours
# 2020-01-26: Daylight: 8.89 hours
# 2020-01-27: Daylight: 8.94 hours
# 2020-01-28: Daylight: 8.99 hours
# 2020-01-29: Daylight: 9.04 hours
# 2020-01-30: Daylight: 9.10 hours
# 2020-01-31: Daylight: 9.15 hours
# 2020-02-01: Daylight: 9.20 hours
# 2020-02-02: Daylight: 9.26 hours
# 2020-02-03: Daylight: 9.31 hours
# 2020-02-04: Daylight: 9.37 hours
# 2020-02-05: Daylight: 9.43 hours
# 2020-02-06: Daylight: 9.48 hours
# 2020-02-07: Daylight: 9.54 hours
# 2020-02-08: Daylight: 9.60 hours
# 2020-02-09: Daylight: 9.66 hours
# 2020-02-10: Daylight: 9.72 hours
# 2020-02-11: Daylight: 9.78 hours
# 2020-02-12: Daylight: 9.84 hours
# 2020-02-13: Daylight: 9.90 hours
# 2020-02-14: Daylight: 9.96 hours
# 2020-02-15: Daylight: 10.02 hours
# 2020-02-16: Daylight: 10.08 hours
# 2020-02-17: Daylight: 10.14 hours
# 2020-02-18: Daylight: 10.21 hours
# 2020-02-19: Daylight: 10.27 hours
# 2020-02-20: Daylight: 10.33 hours
# 2020-02-21: Daylight: 10.39 hours
# 2020-02-22: Daylight: 10.46 hours
# 2020-02-23: Daylight: 10.52 hours
# 2020-02-24: Daylight: 10.58 hours
# 2020-02-25: Daylight: 10.65 hours
# 2020-02-26: Daylight: 10.71 hours
# 2020-02-27: Daylight: 10.78 hours
# 2020-02-28: Daylight: 10.84 hours
# 2020-02-29: Daylight: 10.90 hours
# 2020-03-01: Daylight: 10.97 hours
# 2020-03-02: Daylight: 11.03 hours
# 2020-03-03: Daylight: 11.10 hours
# 2020-03-04: Daylight: 11.16 hours
# 2020-03-05: Daylight: 11.23 hours
# 2020-03-06: Daylight: 11.29 hours
# 2020-03-07: Daylight: 11.36 hours
# 2020-03-08: Daylight: 11.42 hours
# 2020-03-09: Daylight: 11.49 hours
# 2020-03-10: Daylight: 11.55 hours
# 2020-03-11: Daylight: 11.62 hours
# 2020-03-12: Daylight: 11.68 hours
# 2020-03-13: Daylight: 11.75 hours
# 2020-03-14: Daylight: 11.81 hours
# 2020-03-15: Daylight: 11.88 hours
# 2020-03-16: Daylight: 11.94 hours
# 2020-03-17: Daylight: 12.01 hours
# 2020-03-18: Daylight: 12.08 hours
# 2020-03-19: Daylight: 12.14 hours
# 2020-03-20: Daylight: 12.21 hours
# 2020-03-21: Daylight: 12.27 hours
# 2020-03-22: Daylight: 12.34 hours
# 2020-03-23: Daylight: 12.40 hours
# 2020-03-24: Daylight: 12.47 hours
# 2020-03-25: Daylight: 12.53 hours
# 2020-03-26: Daylight: 12.60 hours
# 2020-03-27: Daylight: 12.66 hours
# 2020-03-28: Daylight: 12.73 hours
# 2020-03-29: Daylight: 12.79 hours
# 2020-03-30: Daylight: 12.86 hours
# 2020-03-31: Daylight: 12.92 hours
# 2020-04-01: Daylight: 12.99 hours
# 2020-04-02: Daylight: 13.05 hours
# 2020-04-03: Daylight: 13.12 hours
# 2020-04-04: Daylight: 13.18 hours
# 2020-04-05: Daylight: 13.25 hours
# 2020-04-06: Daylight: 13.31 hours
# 2020-04-07: Daylight: 13.38 hours
# 2020-04-08: Daylight: 13.44 hours
# 2020-04-09: Daylight: 13.50 hours
# 2020-04-10: Daylight: 13.57 hours
# 2020-04-11: Daylight: 13.63 hours
# 2020-04-12: Daylight: 13.70 hours
# 2020-04-13: Daylight: 13.76 hours
# 2020-04-14: Daylight: 13.82 hours
# 2020-04-15: Daylight: 13.88 hours
# 2020-04-16: Daylight: 13.95 hours
# 2020-04-17: Daylight: 14.01 hours
# 2020-04-18: Daylight: 14.07 hours
# 2020-04-19: Daylight: 14.13 hours
# 2020-04-20: Daylight: 14.20 hours
# 2020-04-21: Daylight: 14.26 hours
# 2020-04-22: Daylight: 14.32 hours
# 2020-04-23: Daylight: 14.38 hours
# 2020-04-24: Daylight: 14.44 hours
# 2020-04-25: Daylight: 14.50 hours
# 2020-04-26: Daylight: 14.56 hours
# 2020-04-27: Daylight: 14.62 hours
# 2020-04-28: Daylight: 14.68 hours
# 2020-04-29: Daylight: 14.74 hours
# 2020-04-30: Daylight: 14.80 hours
# 2020-05-01: Daylight: 14.85 hours
# 2020-05-02: Daylight: 14.91 hours
# 2020-05-03: Daylight: 14.97 hours
# 2020-05-04: Daylight: 15.02 hours
# 2020-05-05: Daylight: 15.08 hours
# 2020-05-06: Daylight: 15.14 hours
# 2020-05-07: Daylight: 15.19 hours
# 2020-05-08: Daylight: 15.24 hours
# 2020-05-09: Daylight: 15.30 hours
# 2020-05-10: Daylight: 15.35 hours
# 2020-05-11: Daylight: 15.40 hours
# 2020-05-12: Daylight: 15.45 hours
# 2020-05-13: Daylight: 15.51 hours
# 2020-05-14: Daylight: 15.56 hours
# 2020-05-15: Daylight: 15.60 hours
# 2020-05-16: Daylight: 15.65 hours
# 2020-05-17: Daylight: 15.70 hours
# 2020-05-18: Daylight: 15.75 hours
# 2020-05-19: Daylight: 15.79 hours
# 2020-05-20: Daylight: 15.84 hours
# 2020-05-21: Daylight: 15.88 hours
# 2020-05-22: Daylight: 15.92 hours
# 2020-05-23: Daylight: 15.97 hours
# 2020-05-24: Daylight: 16.01 hours
# 2020-05-25: Daylight: 16.05 hours
# 2020-05-26: Daylight: 16.08 hours
# 2020-05-27: Daylight: 16.12 hours
# 2020-05-28: Daylight: 16.16 hours
# 2020-05-29: Daylight: 16.19 hours
# 2020-05-30: Daylight: 16.22 hours
# 2020-05-31: Daylight: 16.26 hours
# 2020-06-01: Daylight: 16.29 hours
# 2020-06-02: Daylight: 16.32 hours
# 2020-06-03: Daylight: 16.35 hours
# 2020-06-04: Daylight: 16.37 hours
# 2020-06-05: Daylight: 16.40 hours
# 2020-06-06: Daylight: 16.42 hours
# 2020-06-07: Daylight: 16.44 hours
# 2020-06-08: Daylight: 16.46 hours
# 2020-06-09: Daylight: 16.48 hours
# 2020-06-10: Daylight: 16.50 hours
# 2020-06-11: Daylight: 16.52 hours
# 2020-06-12: Daylight: 16.53 hours
# 2020-06-13: Daylight: 16.55 hours
# 2020-06-14: Daylight: 16.56 hours
# 2020-06-15: Daylight: 16.57 hours
# 2020-06-16: Daylight: 16.57 hours
# 2020-06-17: Daylight: 16.58 hours
# 2020-06-18: Daylight: 16.59 hours
# 2020-06-19: Daylight: 16.59 hours
# 2020-06-20: Daylight: 16.59 hours
# 2020-06-21: Daylight: 16.59 hours
# 2020-06-22: Daylight: 16.59 hours
# 2020-06-23: Daylight: 16.59 hours
# 2020-06-24: Daylight: 16.58 hours
# 2020-06-25: Daylight: 16.57 hours
# 2020-06-26: Daylight: 16.57 hours
# 2020-06-27: Daylight: 16.56 hours
# 2020-06-28: Daylight: 16.54 hours
# 2020-06-29: Daylight: 16.53 hours
# 2020-06-30: Daylight: 16.52 hours
# 2020-07-01: Daylight: 16.50 hours
# 2020-07-02: Daylight: 16.48 hours
# 2020-07-03: Daylight: 16.46 hours
# 2020-07-04: Daylight: 16.44 hours
# 2020-07-05: Daylight: 16.42 hours
# 2020-07-06: Daylight: 16.39 hours
# 2020-07-07: Daylight: 16.37 hours
# 2020-07-08: Daylight: 16.34 hours
# 2020-07-09: Daylight: 16.31 hours
# 2020-07-10: Daylight: 16.28 hours
# 2020-07-11: Daylight: 16.25 hours
# 2020-07-12: Daylight: 16.22 hours
# 2020-07-13: Daylight: 16.19 hours
# 2020-07-14: Daylight: 16.15 hours
# 2020-07-15: Daylight: 16.12 hours
# 2020-07-16: Daylight: 16.08 hours
# 2020-07-17: Daylight: 16.04 hours
# 2020-07-18: Daylight: 16.00 hours
# 2020-07-19: Daylight: 15.96 hours
# 2020-07-20: Daylight: 15.92 hours
# 2020-07-21: Daylight: 15.88 hours
# 2020-07-22: Daylight: 15.84 hours
# 2020-07-23: Daylight: 15.79 hours
# 2020-07-24: Daylight: 15.75 hours
# 2020-07-25: Daylight: 15.70 hours
# 2020-07-26: Daylight: 15.65 hours
# 2020-07-27: Daylight: 15.61 hours
# 2020-07-28: Daylight: 15.56 hours
# 2020-07-29: Daylight: 15.51 hours
# 2020-07-30: Daylight: 15.46 hours
# 2020-07-31: Daylight: 15.41 hours
# 2020-08-01: Daylight: 15.35 hours
# 2020-08-02: Daylight: 15.30 hours
# 2020-08-03: Daylight: 15.25 hours
# 2020-08-04: Daylight: 15.20 hours
# 2020-08-05: Daylight: 15.14 hours
# 2020-08-06: Daylight: 15.09 hours
# 2020-08-07: Daylight: 15.03 hours
# 2020-08-08: Daylight: 14.98 hours
# 2020-08-09: Daylight: 14.92 hours
# 2020-08-10: Daylight: 14.86 hours
# 2020-08-11: Daylight: 14.81 hours
# 2020-08-12: Daylight: 14.75 hours
# 2020-08-13: Daylight: 14.69 hours
# 2020-08-14: Daylight: 14.63 hours
# 2020-08-15: Daylight: 14.57 hours
# 2020-08-16: Daylight: 14.51 hours
# 2020-08-17: Daylight: 14.46 hours
# 2020-08-18: Daylight: 14.40 hours
# 2020-08-19: Daylight: 14.34 hours
# 2020-08-20: Daylight: 14.28 hours
# 2020-08-21: Daylight: 14.21 hours
# 2020-08-22: Daylight: 14.15 hours
# 2020-08-23: Daylight: 14.09 hours
# 2020-08-24: Daylight: 14.03 hours
# 2020-08-25: Daylight: 13.97 hours
# 2020-08-26: Daylight: 13.91 hours
# 2020-08-27: Daylight: 13.85 hours
# 2020-08-28: Daylight: 13.78 hours
# 2020-08-29: Daylight: 13.72 hours
# 2020-08-30: Daylight: 13.66 hours
# 2020-08-31: Daylight: 13.60 hours
# 2020-09-01: Daylight: 13.53 hours
# 2020-09-02: Daylight: 13.47 hours
# 2020-09-03: Daylight: 13.41 hours
# 2020-09-04: Daylight: 13.34 hours
# 2020-09-05: Daylight: 13.28 hours
# 2020-09-06: Daylight: 13.22 hours
# 2020-09-07: Daylight: 13.15 hours
# 2020-09-08: Daylight: 13.09 hours
# 2020-09-09: Daylight: 13.03 hours
# 2020-09-10: Daylight: 12.96 hours
# 2020-09-11: Daylight: 12.90 hours
# 2020-09-12: Daylight: 12.83 hours
# 2020-09-13: Daylight: 12.77 hours
# 2020-09-14: Daylight: 12.71 hours
# 2020-09-15: Daylight: 12.64 hours
# 2020-09-16: Daylight: 12.58 hours
# 2020-09-17: Daylight: 12.51 hours
# 2020-09-18: Daylight: 12.45 hours
# 2020-09-19: Daylight: 12.38 hours
# 2020-09-20: Daylight: 12.32 hours
# 2020-09-21: Daylight: 12.26 hours
# 2020-09-22: Daylight: 12.19 hours
# 2020-09-23: Daylight: 12.13 hours
# 2020-09-24: Daylight: 12.06 hours
# 2020-09-25: Daylight: 12.00 hours
# 2020-09-26: Daylight: 11.93 hours
# 2020-09-27: Daylight: 11.87 hours
# 2020-09-28: Daylight: 11.80 hours
# 2020-09-29: Daylight: 11.74 hours
# 2020-09-30: Daylight: 11.68 hours
# 2020-10-01: Daylight: 11.61 hours
# 2020-10-02: Daylight: 11.55 hours
# 2020-10-03: Daylight: 11.48 hours
# 2020-10-04: Daylight: 11.42 hours
# 2020-10-05: Daylight: 11.35 hours
# 2020-10-06: Daylight: 11.29 hours
# 2020-10-07: Daylight: 11.23 hours
# 2020-10-08: Daylight: 11.16 hours
# 2020-10-09: Daylight: 11.10 hours
# 2020-10-10: Daylight: 11.04 hours
# 2020-10-11: Daylight: 10.97 hours
# 2020-10-12: Daylight: 10.91 hours
# 2020-10-13: Daylight: 10.84 hours
# 2020-10-14: Daylight: 10.78 hours
# 2020-10-15: Daylight: 10.72 hours
# 2020-10-16: Daylight: 10.66 hours
# 2020-10-17: Daylight: 10.59 hours
# 2020-10-18: Daylight: 10.53 hours
# 2020-10-19: Daylight: 10.47 hours
# 2020-10-20: Daylight: 10.41 hours
# 2020-10-21: Daylight: 10.34 hours
# 2020-10-22: Daylight: 10.28 hours
# 2020-10-23: Daylight: 10.22 hours
# 2020-10-24: Daylight: 10.16 hours
# 2020-10-25: Daylight: 10.10 hours
# 2020-10-26: Daylight: 10.04 hours
# 2020-10-27: Daylight: 9.98 hours
# 2020-10-28: Daylight: 9.92 hours
# 2020-10-29: Daylight: 9.86 hours
# 2020-10-30: Daylight: 9.80 hours
# 2020-10-31: Daylight: 9.74 hours
# 2020-11-01: Daylight: 9.68 hours
# 2020-11-02: Daylight: 9.62 hours
# 2020-11-03: Daylight: 9.56 hours
# 2020-11-04: Daylight: 9.51 hours
# 2020-11-05: Daylight: 9.45 hours
# 2020-11-06: Daylight: 9.39 hours
# 2020-11-07: Daylight: 9.34 hours
# 2020-11-08: Daylight: 9.28 hours
# 2020-11-09: Daylight: 9.23 hours
# 2020-11-10: Daylight: 9.17 hours
# 2020-11-11: Daylight: 9.12 hours
# 2020-11-12: Daylight: 9.07 hours
# 2020-11-13: Daylight: 9.01 hours
# 2020-11-14: Daylight: 8.96 hours
# 2020-11-15: Daylight: 8.91 hours
# 2020-11-16: Daylight: 8.86 hours
# 2020-11-17: Daylight: 8.81 hours
# 2020-11-18: Daylight: 8.77 hours
# 2020-11-19: Daylight: 8.72 hours
# 2020-11-20: Daylight: 8.67 hours
# 2020-11-21: Daylight: 8.63 hours
# 2020-11-22: Daylight: 8.58 hours
# 2020-11-23: Daylight: 8.54 hours
# 2020-11-24: Daylight: 8.50 hours
# 2020-11-25: Daylight: 8.46 hours
# 2020-11-26: Daylight: 8.42 hours
# 2020-11-27: Daylight: 8.38 hours
# 2020-11-28: Daylight: 8.34 hours
# 2020-11-29: Daylight: 8.31 hours
# 2020-11-30: Daylight: 8.27 hours
# 2020-12-01: Daylight: 8.24 hours
# 2020-12-02: Daylight: 8.21 hours
# 2020-12-03: Daylight: 8.18 hours
# 2020-12-04: Daylight: 8.15 hours
# 2020-12-05: Daylight: 8.12 hours
# 2020-12-06: Daylight: 8.09 hours
# 2020-12-07: Daylight: 8.07 hours
# 2020-12-08: Daylight: 8.05 hours
# 2020-12-09: Daylight: 8.03 hours
# 2020-12-10: Daylight: 8.01 hours
# 2020-12-11: Daylight: 7.99 hours
# 2020-12-12: Daylight: 7.97 hours
# 2020-12-13: Daylight: 7.96 hours
# 2020-12-14: Daylight: 7.94 hours
# 2020-12-15: Daylight: 7.93 hours
# 2020-12-16: Daylight: 7.92 hours
# 2020-12-17: Daylight: 7.91 hours
# 2020-12-18: Daylight: 7.91 hours
# 2020-12-19: Daylight: 7.90 hours
# 2020-12-20: Daylight: 7.90 hours
# 2020-12-21: Daylight: 7.90 hours
# 2020-12-22: Daylight: 7.90 hours
# 2020-12-23: Daylight: 7.90 hours
# 2020-12-24: Daylight: 7.91 hours
# 2020-12-25: Daylight: 7.92 hours
# 2020-12-26: Daylight: 7.92 hours
# 2020-12-27: Daylight: 7.93 hours
# 2020-12-28: Daylight: 7.94 hours
# 2020-12-29: Daylight: 7.96 hours
# 2020-12-30: Daylight: 7.97 hours
# 2020-12-31: Daylight: 7.99 hours
# 2021-01-01: Daylight: 8.01 hours
# 2021-01-02: Daylight: 8.03 hours
# 2021-01-03: Daylight: 8.05 hours
# 2021-01-04: Daylight: 8.07 hours
# 2021-01-05: Daylight: 8.10 hours
# 2021-01-06: Daylight: 8.12 hours
# 2021-01-07: Daylight: 8.15 hours
# 2021-01-08: Daylight: 8.18 hours
# 2021-01-09: Daylight: 8.21 hours
# 2021-01-10: Daylight: 8.25 hours
# 2021-01-11: Daylight: 8.28 hours
# 2021-01-12: Daylight: 8.31 hours
# 2021-01-13: Daylight: 8.35 hours
# 2021-01-14: Daylight: 8.39 hours
# 2021-01-15: Daylight: 8.43 hours
# 2021-01-16: Daylight: 8.47 hours
# 2021-01-17: Daylight: 8.51 hours
# 2021-01-18: Daylight: 8.55 hours
# 2021-01-19: Daylight: 8.59 hours
# 2021-01-20: Daylight: 8.64 hours
# 2021-01-21: Daylight: 8.68 hours
# 2021-01-22: Daylight: 8.73 hours
# 2021-01-23: Daylight: 8.78 hours
# 2021-01-24: Daylight: 8.83 hours
# 2021-01-25: Daylight: 8.88 hours
# 2021-01-26: Daylight: 8.93 hours
# 2021-01-27: Daylight: 8.98 hours
# 2021-01-28: Daylight: 9.03 hours
# 2021-01-29: Daylight: 9.08 hours
# 2021-01-30: Daylight: 9.14 hours
# 2021-01-31: Daylight: 9.19 hours
# 2021-02-01: Daylight: 9.24 hours
# 2021-02-02: Daylight: 9.30 hours
# 2021-02-03: Daylight: 9.36 hours
# 2021-02-04: Daylight: 9.41 hours
# 2021-02-05: Daylight: 9.47 hours
# 2021-02-06: Daylight: 9.53 hours
# 2021-02-07: Daylight: 9.59 hours
# 2021-02-08: Daylight: 9.64 hours
# 2021-02-09: Daylight: 9.70 hours
# 2021-02-10: Daylight: 9.76 hours
# 2021-02-11: Daylight: 9.82 hours
# 2021-02-12: Daylight: 9.88 hours
# 2021-02-13: Daylight: 9.94 hours
# 2021-02-14: Daylight: 10.01 hours
# 2021-02-15: Daylight: 10.07 hours
# 2021-02-16: Daylight: 10.13 hours
# 2021-02-17: Daylight: 10.19 hours
# 2021-02-18: Daylight: 10.25 hours
# 2021-02-19: Daylight: 10.32 hours
# 2021-02-20: Daylight: 10.38 hours
# 2021-02-21: Daylight: 10.44 hours
# 2021-02-22: Daylight: 10.50 hours
# 2021-02-23: Daylight: 10.57 hours
# 2021-02-24: Daylight: 10.63 hours
# 2021-02-25: Daylight: 10.70 hours
# 2021-02-26: Daylight: 10.76 hours
# 2021-02-27: Daylight: 10.82 hours
# 2021-02-28: Daylight: 10.89 hours
# 2021-03-01: Daylight: 10.95 hours
# 2021-03-02: Daylight: 11.02 hours
# 2021-03-03: Daylight: 11.08 hours
# 2021-03-04: Daylight: 11.15 hours
# 2021-03-05: Daylight: 11.21 hours
# 2021-03-06: Daylight: 11.28 hours
# 2021-03-07: Daylight: 11.34 hours
# 2021-03-08: Daylight: 11.41 hours
# 2021-03-09: Daylight: 11.47 hours
# 2021-03-10: Daylight: 11.54 hours
# 2021-03-11: Daylight: 11.60 hours
# 2021-03-12: Daylight: 11.67 hours
# 2021-03-13: Daylight: 11.73 hours
# 2021-03-14: Daylight: 11.80 hours
# 2021-03-15: Daylight: 11.86 hours
# 2021-03-16: Daylight: 11.93 hours
# 2021-03-17: Daylight: 11.99 hours
# 2021-03-18: Daylight: 12.06 hours
# 2021-03-19: Daylight: 12.13 hours
# 2021-03-20: Daylight: 12.19 hours
# 2021-03-21: Daylight: 12.26 hours
# 2021-03-22: Daylight: 12.32 hours
# 2021-03-23: Daylight: 12.39 hours
# 2021-03-24: Daylight: 12.45 hours
# 2021-03-25: Daylight: 12.52 hours
# 2021-03-26: Daylight: 12.58 hours
# 2021-03-27: Daylight: 12.65 hours
# 2021-03-28: Daylight: 12.71 hours
# 2021-03-29: Daylight: 12.78 hours
# 2021-03-30: Daylight: 12.84 hours
# 2021-03-31: Daylight: 12.91 hours
# 2021-04-01: Daylight: 12.97 hours
# 2021-04-02: Daylight: 13.04 hours
# 2021-04-03: Daylight: 13.10 hours
# 2021-04-04: Daylight: 13.17 hours
# 2021-04-05: Daylight: 13.23 hours
# 2021-04-06: Daylight: 13.30 hours
# 2021-04-07: Daylight: 13.36 hours
# 2021-04-08: Daylight: 13.42 hours
# 2021-04-09: Daylight: 13.49 hours
# 2021-04-10: Daylight: 13.55 hours
# 2021-04-11: Daylight: 13.62 hours
# 2021-04-12: Daylight: 13.68 hours
# 2021-04-13: Daylight: 13.74 hours
# 2021-04-14: Daylight: 13.81 hours
# 2021-04-15: Daylight: 13.87 hours
# 2021-04-16: Daylight: 13.93 hours
# 2021-04-17: Daylight: 14.00 hours
# 2021-04-18: Daylight: 14.06 hours
# 2021-04-19: Daylight: 14.12 hours
# 2021-04-20: Daylight: 14.18 hours
# 2021-04-21: Daylight: 14.24 hours
# 2021-04-22: Daylight: 14.30 hours
# 2021-04-23: Daylight: 14.37 hours
# 2021-04-24: Daylight: 14.43 hours
# 2021-04-25: Daylight: 14.49 hours
# 2021-04-26: Daylight: 14.55 hours
# 2021-04-27: Daylight: 14.61 hours
# 2021-04-28: Daylight: 14.66 hours
# 2021-04-29: Daylight: 14.72 hours
# 2021-04-30: Daylight: 14.78 hours
# 2021-05-01: Daylight: 14.84 hours
# 2021-05-02: Daylight: 14.90 hours
# 2021-05-03: Daylight: 14.95 hours
# 2021-05-04: Daylight: 15.01 hours
# 2021-05-05: Daylight: 15.07 hours
# 2021-05-06: Daylight: 15.12 hours
# 2021-05-07: Daylight: 15.18 hours
# 2021-05-08: Daylight: 15.23 hours
# 2021-05-09: Daylight: 15.29 hours
# 2021-05-10: Daylight: 15.34 hours
# 2021-05-11: Daylight: 15.39 hours
# 2021-05-12: Daylight: 15.44 hours
# 2021-05-13: Daylight: 15.49 hours
# 2021-05-14: Daylight: 15.54 hours
# 2021-05-15: Daylight: 15.59 hours
# 2021-05-16: Daylight: 15.64 hours
# 2021-05-17: Daylight: 15.69 hours
# 2021-05-18: Daylight: 15.74 hours
# 2021-05-19: Daylight: 15.78 hours
# 2021-05-20: Daylight: 15.83 hours
# 2021-05-21: Daylight: 15.87 hours
# 2021-05-22: Daylight: 15.91 hours
# 2021-05-23: Daylight: 15.96 hours
# 2021-05-24: Daylight: 16.00 hours
# 2021-05-25: Daylight: 16.04 hours
# 2021-05-26: Daylight: 16.07 hours
# 2021-05-27: Daylight: 16.11 hours
# 2021-05-28: Daylight: 16.15 hours
# 2021-05-29: Daylight: 16.18 hours
# 2021-05-30: Daylight: 16.22 hours
# 2021-05-31: Daylight: 16.25 hours
# 2021-06-01: Daylight: 16.28 hours
# 2021-06-02: Daylight: 16.31 hours
# 2021-06-03: Daylight: 16.34 hours
# 2021-06-04: Daylight: 16.37 hours
# 2021-06-05: Daylight: 16.39 hours
# 2021-06-06: Daylight: 16.42 hours
# 2021-06-07: Daylight: 16.44 hours
# 2021-06-08: Daylight: 16.46 hours
# 2021-06-09: Daylight: 16.48 hours
# 2021-06-10: Daylight: 16.50 hours
# 2021-06-11: Daylight: 16.51 hours
# 2021-06-12: Daylight: 16.53 hours
# 2021-06-13: Daylight: 16.54 hours
# 2021-06-14: Daylight: 16.55 hours
# 2021-06-15: Daylight: 16.56 hours
# 2021-06-16: Daylight: 16.57 hours
# 2021-06-17: Daylight: 16.58 hours
# 2021-06-18: Daylight: 16.59 hours
# 2021-06-19: Daylight: 16.59 hours
# 2021-06-20: Daylight: 16.59 hours
# 2021-06-21: Daylight: 16.59 hours
# 2021-06-22: Daylight: 16.59 hours
# 2021-06-23: Daylight: 16.59 hours
# 2021-06-24: Daylight: 16.58 hours
# 2021-06-25: Daylight: 16.58 hours
# 2021-06-26: Daylight: 16.57 hours
# 2021-06-27: Daylight: 16.56 hours
# 2021-06-28: Daylight: 16.55 hours
# 2021-06-29: Daylight: 16.53 hours
# 2021-06-30: Daylight: 16.52 hours
# 2021-07-01: Daylight: 16.50 hours
# 2021-07-02: Daylight: 16.49 hours
# 2021-07-03: Daylight: 16.47 hours
# 2021-07-04: Daylight: 16.45 hours
# 2021-07-05: Daylight: 16.42 hours
# 2021-07-06: Daylight: 16.40 hours
# 2021-07-07: Daylight: 16.38 hours
# 2021-07-08: Daylight: 16.35 hours
# 2021-07-09: Daylight: 16.32 hours
# 2021-07-10: Daylight: 16.29 hours
# 2021-07-11: Daylight: 16.26 hours
# 2021-07-12: Daylight: 16.23 hours
# 2021-07-13: Daylight: 16.20 hours
# 2021-07-14: Daylight: 16.16 hours
# 2021-07-15: Daylight: 16.13 hours
# 2021-07-16: Daylight: 16.09 hours
# 2021-07-17: Daylight: 16.05 hours
# 2021-07-18: Daylight: 16.01 hours
# 2021-07-19: Daylight: 15.97 hours
# 2021-07-20: Daylight: 15.93 hours
# 2021-07-21: Daylight: 15.89 hours
# 2021-07-22: Daylight: 15.85 hours
# 2021-07-23: Daylight: 15.80 hours
# 2021-07-24: Daylight: 15.76 hours
# 2021-07-25: Daylight: 15.71 hours
# 2021-07-26: Daylight: 15.66 hours
# 2021-07-27: Daylight: 15.62 hours
# 2021-07-28: Daylight: 15.57 hours
# 2021-07-29: Daylight: 15.52 hours
# 2021-07-30: Daylight: 15.47 hours
# 2021-07-31: Daylight: 15.42 hours
# 2021-08-01: Daylight: 15.37 hours
# 2021-08-02: Daylight: 15.32 hours
# 2021-08-03: Daylight: 15.26 hours
# 2021-08-04: Daylight: 15.21 hours
# 2021-08-05: Daylight: 15.16 hours
# 2021-08-06: Daylight: 15.10 hours
# 2021-08-07: Daylight: 15.05 hours
# 2021-08-08: Daylight: 14.99 hours
# 2021-08-09: Daylight: 14.93 hours
# 2021-08-10: Daylight: 14.88 hours
# 2021-08-11: Daylight: 14.82 hours
# 2021-08-12: Daylight: 14.76 hours
# 2021-08-13: Daylight: 14.70 hours
# 2021-08-14: Daylight: 14.65 hours
# 2021-08-15: Daylight: 14.59 hours
# 2021-08-16: Daylight: 14.53 hours
# 2021-08-17: Daylight: 14.47 hours
# 2021-08-18: Daylight: 14.41 hours
# 2021-08-19: Daylight: 14.35 hours
# 2021-08-20: Daylight: 14.29 hours
# 2021-08-21: Daylight: 14.23 hours
# 2021-08-22: Daylight: 14.17 hours
# 2021-08-23: Daylight: 14.11 hours
# 2021-08-24: Daylight: 14.05 hours
# 2021-08-25: Daylight: 13.98 hours
# 2021-08-26: Daylight: 13.92 hours
# 2021-08-27: Daylight: 13.86 hours
# 2021-08-28: Daylight: 13.80 hours
# 2021-08-29: Daylight: 13.74 hours
# 2021-08-30: Daylight: 13.67 hours
# 2021-08-31: Daylight: 13.61 hours
# 2021-09-01: Daylight: 13.55 hours
# 2021-09-02: Daylight: 13.49 hours
# 2021-09-03: Daylight: 13.42 hours
# 2021-09-04: Daylight: 13.36 hours
# 2021-09-05: Daylight: 13.30 hours
# 2021-09-06: Daylight: 13.23 hours
# 2021-09-07: Daylight: 13.17 hours
# 2021-09-08: Daylight: 13.10 hours
# 2021-09-09: Daylight: 13.04 hours
# 2021-09-10: Daylight: 12.98 hours
# 2021-09-11: Daylight: 12.91 hours
# 2021-09-12: Daylight: 12.85 hours
# 2021-09-13: Daylight: 12.79 hours
# 2021-09-14: Daylight: 12.72 hours
# 2021-09-15: Daylight: 12.66 hours
# 2021-09-16: Daylight: 12.59 hours
# 2021-09-17: Daylight: 12.53 hours
# 2021-09-18: Daylight: 12.46 hours
# 2021-09-19: Daylight: 12.40 hours
# 2021-09-20: Daylight: 12.34 hours
# 2021-09-21: Daylight: 12.27 hours
# 2021-09-22: Daylight: 12.21 hours
# 2021-09-23: Daylight: 12.14 hours
# 2021-09-24: Daylight: 12.08 hours
# 2021-09-25: Daylight: 12.01 hours
# 2021-09-26: Daylight: 11.95 hours
# 2021-09-27: Daylight: 11.88 hours
# 2021-09-28: Daylight: 11.82 hours
# 2021-09-29: Daylight: 11.76 hours
# 2021-09-30: Daylight: 11.69 hours
# 2021-10-01: Daylight: 11.63 hours
# 2021-10-02: Daylight: 11.56 hours
# 2021-10-03: Daylight: 11.50 hours
# 2021-10-04: Daylight: 11.43 hours
# 2021-10-05: Daylight: 11.37 hours
# 2021-10-06: Daylight: 11.31 hours
# 2021-10-07: Daylight: 11.24 hours
# 2021-10-08: Daylight: 11.18 hours
# 2021-10-09: Daylight: 11.11 hours
# 2021-10-10: Daylight: 11.05 hours
# 2021-10-11: Daylight: 10.99 hours
# 2021-10-12: Daylight: 10.92 hours
# 2021-10-13: Daylight: 10.86 hours
# 2021-10-14: Daylight: 10.80 hours
# 2021-10-15: Daylight: 10.73 hours
# 2021-10-16: Daylight: 10.67 hours
# 2021-10-17: Daylight: 10.61 hours
# 2021-10-18: Daylight: 10.54 hours
# 2021-10-19: Daylight: 10.48 hours
# 2021-10-20: Daylight: 10.42 hours
# 2021-10-21: Daylight: 10.36 hours
# 2021-10-22: Daylight: 10.30 hours
# 2021-10-23: Daylight: 10.23 hours
# 2021-10-24: Daylight: 10.17 hours
# 2021-10-25: Daylight: 10.11 hours
# 2021-10-26: Daylight: 10.05 hours
# 2021-10-27: Daylight: 9.99 hours
# 2021-10-28: Daylight: 9.93 hours
# 2021-10-29: Daylight: 9.87 hours
# 2021-10-30: Daylight: 9.81 hours
# 2021-10-31: Daylight: 9.75 hours
# 2021-11-01: Daylight: 9.69 hours
# 2021-11-02: Daylight: 9.63 hours
# 2021-11-03: Daylight: 9.58 hours
# 2021-11-04: Daylight: 9.52 hours
# 2021-11-05: Daylight: 9.46 hours
# 2021-11-06: Daylight: 9.41 hours
# 2021-11-07: Daylight: 9.35 hours
# 2021-11-08: Daylight: 9.29 hours
# 2021-11-09: Daylight: 9.24 hours
# 2021-11-10: Daylight: 9.19 hours
# 2021-11-11: Daylight: 9.13 hours
# 2021-11-12: Daylight: 9.08 hours
# 2021-11-13: Daylight: 9.03 hours
# 2021-11-14: Daylight: 8.98 hours
# 2021-11-15: Daylight: 8.92 hours
# 2021-11-16: Daylight: 8.88 hours
# 2021-11-17: Daylight: 8.83 hours
# 2021-11-18: Daylight: 8.78 hours
# 2021-11-19: Daylight: 8.73 hours
# 2021-11-20: Daylight: 8.68 hours
# 2021-11-21: Daylight: 8.64 hours
# 2021-11-22: Daylight: 8.60 hours
# 2021-11-23: Daylight: 8.55 hours
# 2021-11-24: Daylight: 8.51 hours
# 2021-11-25: Daylight: 8.47 hours
# 2021-11-26: Daylight: 8.43 hours
# 2021-11-27: Daylight: 8.39 hours
# 2021-11-28: Daylight: 8.35 hours
# 2021-11-29: Daylight: 8.32 hours
# 2021-11-30: Daylight: 8.28 hours
# 2021-12-01: Daylight: 8.25 hours
# 2021-12-02: Daylight: 8.22 hours
# 2021-12-03: Daylight: 8.18 hours
# 2021-12-04: Daylight: 8.16 hours
# 2021-12-05: Daylight: 8.13 hours
# 2021-12-06: Daylight: 8.10 hours
# 2021-12-07: Daylight: 8.08 hours
# 2021-12-08: Daylight: 8.05 hours
# 2021-12-09: Daylight: 8.03 hours
# 2021-12-10: Daylight: 8.01 hours
# 2021-12-11: Daylight: 7.99 hours
# 2021-12-12: Daylight: 7.98 hours
# 2021-12-13: Daylight: 7.96 hours
# 2021-12-14: Daylight: 7.95 hours
# 2021-12-15: Daylight: 7.93 hours
# 2021-12-16: Daylight: 7.92 hours
# 2021-12-17: Daylight: 7.92 hours
# 2021-12-18: Daylight: 7.91 hours
# 2021-12-19: Daylight: 7.90 hours
# 2021-12-20: Daylight: 7.90 hours
# 2021-12-21: Daylight: 7.90 hours
# 2021-12-22: Daylight: 7.90 hours
# 2021-12-23: Daylight: 7.90 hours
# 2021-12-24: Daylight: 7.91 hours
# 2021-12-25: Daylight: 7.91 hours
# 2021-12-26: Daylight: 7.92 hours
# 2021-12-27: Daylight: 7.93 hours
# 2021-12-28: Daylight: 7.94 hours
# 2021-12-29: Daylight: 7.95 hours
# 2021-12-30: Daylight: 7.97 hours
# 2021-12-31: Daylight: 7.99 hours
# 2022-01-01: Daylight: 8.00 hours
# 2022-01-02: Daylight: 8.02 hours
# 2022-01-03: Daylight: 8.04 hours
# 2022-01-04: Daylight: 8.07 hours
# 2022-01-05: Daylight: 8.09 hours
# 2022-01-06: Daylight: 8.12 hours
# 2022-01-07: Daylight: 8.15 hours
# 2022-01-08: Daylight: 8.17 hours
# 2022-01-09: Daylight: 8.20 hours
# 2022-01-10: Daylight: 8.24 hours
# 2022-01-11: Daylight: 8.27 hours
# 2022-01-12: Daylight: 8.31 hours
# 2022-01-13: Daylight: 8.34 hours
# 2022-01-14: Daylight: 8.38 hours
# 2022-01-15: Daylight: 8.42 hours
# 2022-01-16: Daylight: 8.46 hours
# 2022-01-17: Daylight: 8.50 hours
# 2022-01-18: Daylight: 8.54 hours
# 2022-01-19: Daylight: 8.58 hours
# 2022-01-20: Daylight: 8.63 hours
# 2022-01-21: Daylight: 8.67 hours
# 2022-01-22: Daylight: 8.72 hours
# 2022-01-23: Daylight: 8.77 hours
# 2022-01-24: Daylight: 8.81 hours
# 2022-01-25: Daylight: 8.86 hours
# 2022-01-26: Daylight: 8.91 hours
# 2022-01-27: Daylight: 8.97 hours
# 2022-01-28: Daylight: 9.02 hours
# 2022-01-29: Daylight: 9.07 hours
# 2022-01-30: Daylight: 9.12 hours
# 2022-01-31: Daylight: 9.18 hours
# 2022-02-01: Daylight: 9.23 hours
# 2022-02-02: Daylight: 9.29 hours
# 2022-02-03: Daylight: 9.34 hours
# 2022-02-04: Daylight: 9.40 hours
# 2022-02-05: Daylight: 9.46 hours
# 2022-02-06: Daylight: 9.51 hours
# 2022-02-07: Daylight: 9.57 hours
# 2022-02-08: Daylight: 9.63 hours
# 2022-02-09: Daylight: 9.69 hours
# 2022-02-10: Daylight: 9.75 hours
# 2022-02-11: Daylight: 9.81 hours
# 2022-02-12: Daylight: 9.87 hours
# 2022-02-13: Daylight: 9.93 hours
# 2022-02-14: Daylight: 9.99 hours
# 2022-02-15: Daylight: 10.05 hours
# 2022-02-16: Daylight: 10.11 hours
# 2022-02-17: Daylight: 10.18 hours
# 2022-02-18: Daylight: 10.24 hours
# 2022-02-19: Daylight: 10.30 hours
# 2022-02-20: Daylight: 10.36 hours
# 2022-02-21: Daylight: 10.43 hours
# 2022-02-22: Daylight: 10.49 hours
# 2022-02-23: Daylight: 10.55 hours
# 2022-02-24: Daylight: 10.62 hours
# 2022-02-25: Daylight: 10.68 hours
# 2022-02-26: Daylight: 10.74 hours
# 2022-02-27: Daylight: 10.81 hours
# 2022-02-28: Daylight: 10.87 hours
# 2022-03-01: Daylight: 10.94 hours
# 2022-03-02: Daylight: 11.00 hours
# 2022-03-03: Daylight: 11.07 hours
# 2022-03-04: Daylight: 11.13 hours
# 2022-03-05: Daylight: 11.20 hours
# 2022-03-06: Daylight: 11.26 hours
# 2022-03-07: Daylight: 11.33 hours
# 2022-03-08: Daylight: 11.39 hours
# 2022-03-09: Daylight: 11.46 hours
# 2022-03-10: Daylight: 11.52 hours
# 2022-03-11: Daylight: 11.59 hours
# 2022-03-12: Daylight: 11.65 hours
# 2022-03-13: Daylight: 11.72 hours
# 2022-03-14: Daylight: 11.78 hours
# 2022-03-15: Daylight: 11.85 hours
# 2022-03-16: Daylight: 11.91 hours
# 2022-03-17: Daylight: 11.98 hours
# 2022-03-18: Daylight: 12.04 hours
# 2022-03-19: Daylight: 12.11 hours
# 2022-03-20: Daylight: 12.17 hours
# 2022-03-21: Daylight: 12.24 hours
# 2022-03-22: Daylight: 12.31 hours
# 2022-03-23: Daylight: 12.37 hours
# 2022-03-24: Daylight: 12.44 hours
# 2022-03-25: Daylight: 12.50 hours
# 2022-03-26: Daylight: 12.57 hours
# 2022-03-27: Daylight: 12.63 hours
# 2022-03-28: Daylight: 12.70 hours
# 2022-03-29: Daylight: 12.76 hours
# 2022-03-30: Daylight: 12.83 hours
# 2022-03-31: Daylight: 12.89 hours
# 2022-04-01: Daylight: 12.96 hours
# 2022-04-02: Daylight: 13.02 hours
# 2022-04-03: Daylight: 13.09 hours
# 2022-04-04: Daylight: 13.15 hours
# 2022-04-05: Daylight: 13.22 hours
# 2022-04-06: Daylight: 13.28 hours
# 2022-04-07: Daylight: 13.35 hours
# 2022-04-08: Daylight: 13.41 hours
# 2022-04-09: Daylight: 13.47 hours
# 2022-04-10: Daylight: 13.54 hours
# 2022-04-11: Daylight: 13.60 hours
# 2022-04-12: Daylight: 13.66 hours
# 2022-04-13: Daylight: 13.73 hours
# 2022-04-14: Daylight: 13.79 hours
# 2022-04-15: Daylight: 13.85 hours
# 2022-04-16: Daylight: 13.92 hours
# 2022-04-17: Daylight: 13.98 hours
# 2022-04-18: Daylight: 14.04 hours
# 2022-04-19: Daylight: 14.10 hours
# 2022-04-20: Daylight: 14.17 hours
# 2022-04-21: Daylight: 14.23 hours
# 2022-04-22: Daylight: 14.29 hours
# 2022-04-23: Daylight: 14.35 hours
# 2022-04-24: Daylight: 14.41 hours
# 2022-04-25: Daylight: 14.47 hours
# 2022-04-26: Daylight: 14.53 hours
# 2022-04-27: Daylight: 14.59 hours
# 2022-04-28: Daylight: 14.65 hours
# 2022-04-29: Daylight: 14.71 hours
# 2022-04-30: Daylight: 14.77 hours
# 2022-05-01: Daylight: 14.83 hours
# 2022-05-02: Daylight: 14.88 hours
# 2022-05-03: Daylight: 14.94 hours
# 2022-05-04: Daylight: 15.00 hours
# 2022-05-05: Daylight: 15.05 hours
# 2022-05-06: Daylight: 15.11 hours
# 2022-05-07: Daylight: 15.16 hours
# 2022-05-08: Daylight: 15.22 hours
# 2022-05-09: Daylight: 15.27 hours
# 2022-05-10: Daylight: 15.33 hours
# 2022-05-11: Daylight: 15.38 hours
# 2022-05-12: Daylight: 15.43 hours
# 2022-05-13: Daylight: 15.48 hours
# 2022-05-14: Daylight: 15.53 hours
# 2022-05-15: Daylight: 15.58 hours
# 2022-05-16: Daylight: 15.63 hours
# 2022-05-17: Daylight: 15.68 hours
# 2022-05-18: Daylight: 15.72 hours
# 2022-05-19: Daylight: 15.77 hours
# 2022-05-20: Daylight: 15.82 hours
# 2022-05-21: Daylight: 15.86 hours
# 2022-05-22: Daylight: 15.90 hours
# 2022-05-23: Daylight: 15.95 hours
# 2022-05-24: Daylight: 15.99 hours
# 2022-05-25: Daylight: 16.03 hours
# 2022-05-26: Daylight: 16.07 hours
# 2022-05-27: Daylight: 16.10 hours
# 2022-05-28: Daylight: 16.14 hours
# 2022-05-29: Daylight: 16.18 hours
# 2022-05-30: Daylight: 16.21 hours
# 2022-05-31: Daylight: 16.24 hours
# 2022-06-01: Daylight: 16.27 hours
# 2022-06-02: Daylight: 16.30 hours
# 2022-06-03: Daylight: 16.33 hours
# 2022-06-04: Daylight: 16.36 hours
# 2022-06-05: Daylight: 16.39 hours
# 2022-06-06: Daylight: 16.41 hours
# 2022-06-07: Daylight: 16.43 hours
# 2022-06-08: Daylight: 16.46 hours
# 2022-06-09: Daylight: 16.48 hours
# 2022-06-10: Daylight: 16.49 hours
# 2022-06-11: Daylight: 16.51 hours
# 2022-06-12: Daylight: 16.53 hours
# 2022-06-13: Daylight: 16.54 hours
# 2022-06-14: Daylight: 16.55 hours
# 2022-06-15: Daylight: 16.56 hours
# 2022-06-16: Daylight: 16.57 hours
# 2022-06-17: Daylight: 16.58 hours
# 2022-06-18: Daylight: 16.58 hours
# 2022-06-19: Daylight: 16.59 hours
# 2022-06-20: Daylight: 16.59 hours
# 2022-06-21: Daylight: 16.59 hours
# 2022-06-22: Daylight: 16.59 hours
# 2022-06-23: Daylight: 16.59 hours
# 2022-06-24: Daylight: 16.58 hours
# 2022-06-25: Daylight: 16.58 hours
# 2022-06-26: Daylight: 16.57 hours
# 2022-06-27: Daylight: 16.56 hours
# 2022-06-28: Daylight: 16.55 hours
# 2022-06-29: Daylight: 16.54 hours
# 2022-06-30: Daylight: 16.52 hours
# 2022-07-01: Daylight: 16.51 hours
# 2022-07-02: Daylight: 16.49 hours
# 2022-07-03: Daylight: 16.47 hours
# 2022-07-04: Daylight: 16.45 hours
# 2022-07-05: Daylight: 16.43 hours
# 2022-07-06: Daylight: 16.41 hours
# 2022-07-07: Daylight: 16.38 hours
# 2022-07-08: Daylight: 16.36 hours
# 2022-07-09: Daylight: 16.33 hours
# 2022-07-10: Daylight: 16.30 hours
# 2022-07-11: Daylight: 16.27 hours
# 2022-07-12: Daylight: 16.24 hours
# 2022-07-13: Daylight: 16.20 hours
# 2022-07-14: Daylight: 16.17 hours
# 2022-07-15: Daylight: 16.14 hours
# 2022-07-16: Daylight: 16.10 hours
# 2022-07-17: Daylight: 16.06 hours
# 2022-07-18: Daylight: 16.02 hours
# 2022-07-19: Daylight: 15.98 hours
# 2022-07-20: Daylight: 15.94 hours
# 2022-07-21: Daylight: 15.90 hours
# 2022-07-22: Daylight: 15.86 hours
# 2022-07-23: Daylight: 15.81 hours
# 2022-07-24: Daylight: 15.77 hours
# 2022-07-25: Daylight: 15.72 hours
# 2022-07-26: Daylight: 15.68 hours
# 2022-07-27: Daylight: 15.63 hours
# 2022-07-28: Daylight: 15.58 hours
# 2022-07-29: Daylight: 15.53 hours
# 2022-07-30: Daylight: 15.48 hours
# 2022-07-31: Daylight: 15.43 hours
# 2022-08-01: Daylight: 15.38 hours
# 2022-08-02: Daylight: 15.33 hours
# 2022-08-03: Daylight: 15.27 hours
# 2022-08-04: Daylight: 15.22 hours
# 2022-08-05: Daylight: 15.17 hours
# 2022-08-06: Daylight: 15.11 hours
# 2022-08-07: Daylight: 15.06 hours
# 2022-08-08: Daylight: 15.00 hours
# 2022-08-09: Daylight: 14.95 hours
# 2022-08-10: Daylight: 14.89 hours
# 2022-08-11: Daylight: 14.83 hours
# 2022-08-12: Daylight: 14.78 hours
# 2022-08-13: Daylight: 14.72 hours
# 2022-08-14: Daylight: 14.66 hours
# 2022-08-15: Daylight: 14.60 hours
# 2022-08-16: Daylight: 14.54 hours
# 2022-08-17: Daylight: 14.48 hours
# 2022-08-18: Daylight: 14.42 hours
# 2022-08-19: Daylight: 14.36 hours
# 2022-08-20: Daylight: 14.30 hours
# 2022-08-21: Daylight: 14.24 hours
# 2022-08-22: Daylight: 14.18 hours
# 2022-08-23: Daylight: 14.12 hours
# 2022-08-24: Daylight: 14.06 hours
# 2022-08-25: Daylight: 14.00 hours
# 2022-08-26: Daylight: 13.94 hours
# 2022-08-27: Daylight: 13.88 hours
# 2022-08-28: Daylight: 13.81 hours
# 2022-08-29: Daylight: 13.75 hours
# 2022-08-30: Daylight: 13.69 hours
# 2022-08-31: Daylight: 13.63 hours
# 2022-09-01: Daylight: 13.56 hours
# 2022-09-02: Daylight: 13.50 hours
# 2022-09-03: Daylight: 13.44 hours
# 2022-09-04: Daylight: 13.37 hours
# 2022-09-05: Daylight: 13.31 hours
# 2022-09-06: Daylight: 13.25 hours
# 2022-09-07: Daylight: 13.18 hours
# 2022-09-08: Daylight: 13.12 hours
# 2022-09-09: Daylight: 13.06 hours
# 2022-09-10: Daylight: 12.99 hours
# 2022-09-11: Daylight: 12.93 hours
# 2022-09-12: Daylight: 12.86 hours
# 2022-09-13: Daylight: 12.80 hours
# 2022-09-14: Daylight: 12.74 hours
# 2022-09-15: Daylight: 12.67 hours
# 2022-09-16: Daylight: 12.61 hours
# 2022-09-17: Daylight: 12.54 hours
# 2022-09-18: Daylight: 12.48 hours
# 2022-09-19: Daylight: 12.42 hours
# 2022-09-20: Daylight: 12.35 hours
# 2022-09-21: Daylight: 12.29 hours
# 2022-09-22: Daylight: 12.22 hours
# 2022-09-23: Daylight: 12.16 hours
# 2022-09-24: Daylight: 12.09 hours
# 2022-09-25: Daylight: 12.03 hours
# 2022-09-26: Daylight: 11.96 hours
# 2022-09-27: Daylight: 11.90 hours
# 2022-09-28: Daylight: 11.84 hours
# 2022-09-29: Daylight: 11.77 hours
# 2022-09-30: Daylight: 11.71 hours
# 2022-10-01: Daylight: 11.64 hours
# 2022-10-02: Daylight: 11.58 hours
# 2022-10-03: Daylight: 11.51 hours
# 2022-10-04: Daylight: 11.45 hours
# 2022-10-05: Daylight: 11.39 hours
# 2022-10-06: Daylight: 11.32 hours
# 2022-10-07: Daylight: 11.26 hours
# 2022-10-08: Daylight: 11.19 hours
# 2022-10-09: Daylight: 11.13 hours
# 2022-10-10: Daylight: 11.07 hours
# 2022-10-11: Daylight: 11.00 hours
# 2022-10-12: Daylight: 10.94 hours
# 2022-10-13: Daylight: 10.88 hours
# 2022-10-14: Daylight: 10.81 hours
# 2022-10-15: Daylight: 10.75 hours
# 2022-10-16: Daylight: 10.69 hours
# 2022-10-17: Daylight: 10.62 hours
# 2022-10-18: Daylight: 10.56 hours
# 2022-10-19: Daylight: 10.50 hours
# 2022-10-20: Daylight: 10.44 hours
# 2022-10-21: Daylight: 10.37 hours
# 2022-10-22: Daylight: 10.31 hours
# 2022-10-23: Daylight: 10.25 hours
# 2022-10-24: Daylight: 10.19 hours
# 2022-10-25: Daylight: 10.13 hours
# 2022-10-26: Daylight: 10.07 hours
# 2022-10-27: Daylight: 10.00 hours
# 2022-10-28: Daylight: 9.94 hours
# 2022-10-29: Daylight: 9.88 hours
# 2022-10-30: Daylight: 9.82 hours
# 2022-10-31: Daylight: 9.77 hours
# 2022-11-01: Daylight: 9.71 hours
# 2022-11-02: Daylight: 9.65 hours
# 2022-11-03: Daylight: 9.59 hours
# 2022-11-04: Daylight: 9.53 hours
# 2022-11-05: Daylight: 9.48 hours
# 2022-11-06: Daylight: 9.42 hours
# 2022-11-07: Daylight: 9.36 hours
# 2022-11-08: Daylight: 9.31 hours
# 2022-11-09: Daylight: 9.25 hours
# 2022-11-10: Daylight: 9.20 hours
# 2022-11-11: Daylight: 9.14 hours
# 2022-11-12: Daylight: 9.09 hours
# 2022-11-13: Daylight: 9.04 hours
# 2022-11-14: Daylight: 8.99 hours
# 2022-11-15: Daylight: 8.94 hours
# 2022-11-16: Daylight: 8.89 hours
# 2022-11-17: Daylight: 8.84 hours
# 2022-11-18: Daylight: 8.79 hours
# 2022-11-19: Daylight: 8.74 hours
# 2022-11-20: Daylight: 8.70 hours
# 2022-11-21: Daylight: 8.65 hours
# 2022-11-22: Daylight: 8.61 hours
# 2022-11-23: Daylight: 8.56 hours
# 2022-11-24: Daylight: 8.52 hours
# 2022-11-25: Daylight: 8.48 hours
# 2022-11-26: Daylight: 8.44 hours
# 2022-11-27: Daylight: 8.40 hours
# 2022-11-28: Daylight: 8.36 hours
# 2022-11-29: Daylight: 8.32 hours
# 2022-11-30: Daylight: 8.29 hours
# 2022-12-01: Daylight: 8.26 hours
# 2022-12-02: Daylight: 8.22 hours
# 2022-12-03: Daylight: 8.19 hours
# 2022-12-04: Daylight: 8.16 hours
# 2022-12-05: Daylight: 8.13 hours
# 2022-12-06: Daylight: 8.11 hours
# 2022-12-07: Daylight: 8.08 hours
# 2022-12-08: Daylight: 8.06 hours
# 2022-12-09: Daylight: 8.04 hours
# 2022-12-10: Daylight: 8.02 hours
# 2022-12-11: Daylight: 8.00 hours
# 2022-12-12: Daylight: 7.98 hours
# 2022-12-13: Daylight: 7.96 hours
# 2022-12-14: Daylight: 7.95 hours
# 2022-12-15: Daylight: 7.94 hours
# 2022-12-16: Daylight: 7.93 hours
# 2022-12-17: Daylight: 7.92 hours
# 2022-12-18: Daylight: 7.91 hours
# 2022-12-19: Daylight: 7.91 hours
# 2022-12-20: Daylight: 7.90 hours
# 2022-12-21: Daylight: 7.90 hours
# 2022-12-22: Daylight: 7.90 hours
# 2022-12-23: Daylight: 7.90 hours
# 2022-12-24: Daylight: 7.91 hours
# 2022-12-25: Daylight: 7.91 hours
# 2022-12-26: Daylight: 7.92 hours
# 2022-12-27: Daylight: 7.93 hours
# 2022-12-28: Daylight: 7.94 hours
# 2022-12-29: Daylight: 7.95 hours
# 2022-12-30: Daylight: 7.97 hours
# 2022-12-31: Daylight: 7.98 hours
# 2023-01-01: Daylight: 8.00 hours
# 2023-01-02: Daylight: 8.02 hours
# 2023-01-03: Daylight: 8.04 hours
# 2023-01-04: Daylight: 8.06 hours
# 2023-01-05: Daylight: 8.09 hours
# 2023-01-06: Daylight: 8.11 hours
# 2023-01-07: Daylight: 8.14 hours
# 2023-01-08: Daylight: 8.17 hours
# 2023-01-09: Daylight: 8.20 hours
# 2023-01-10: Daylight: 8.23 hours
# 2023-01-11: Daylight: 8.26 hours
# 2023-01-12: Daylight: 8.30 hours
# 2023-01-13: Daylight: 8.33 hours
# 2023-01-14: Daylight: 8.37 hours
# 2023-01-15: Daylight: 8.41 hours
# 2023-01-16: Daylight: 8.45 hours
# 2023-01-17: Daylight: 8.49 hours
# 2023-01-18: Daylight: 8.53 hours
# 2023-01-19: Daylight: 8.57 hours
# 2023-01-20: Daylight: 8.62 hours
# 2023-01-21: Daylight: 8.66 hours
# 2023-01-22: Daylight: 8.71 hours
# 2023-01-23: Daylight: 8.76 hours
# 2023-01-24: Daylight: 8.80 hours
# 2023-01-25: Daylight: 8.85 hours
# 2023-01-26: Daylight: 8.90 hours
# 2023-01-27: Daylight: 8.95 hours
# 2023-01-28: Daylight: 9.00 hours
# 2023-01-29: Daylight: 9.06 hours
# 2023-01-30: Daylight: 9.11 hours
# 2023-01-31: Daylight: 9.16 hours
# 2023-02-01: Daylight: 9.22 hours
# 2023-02-02: Daylight: 9.27 hours
# 2023-02-03: Daylight: 9.33 hours
# 2023-02-04: Daylight: 9.39 hours
# 2023-02-05: Daylight: 9.44 hours
# 2023-02-06: Daylight: 9.50 hours
# 2023-02-07: Daylight: 9.56 hours
# 2023-02-08: Daylight: 9.62 hours
# 2023-02-09: Daylight: 9.67 hours
# 2023-02-10: Daylight: 9.73 hours
# 2023-02-11: Daylight: 9.79 hours
# 2023-02-12: Daylight: 9.85 hours
# 2023-02-13: Daylight: 9.91 hours
# 2023-02-14: Daylight: 9.98 hours
# 2023-02-15: Daylight: 10.04 hours
# 2023-02-16: Daylight: 10.10 hours
# 2023-02-17: Daylight: 10.16 hours
# 2023-02-18: Daylight: 10.22 hours
# 2023-02-19: Daylight: 10.28 hours
# 2023-02-20: Daylight: 10.35 hours
# 2023-02-21: Daylight: 10.41 hours
# 2023-02-22: Daylight: 10.47 hours
# 2023-02-23: Daylight: 10.54 hours
# 2023-02-24: Daylight: 10.60 hours
# 2023-02-25: Daylight: 10.66 hours
# 2023-02-26: Daylight: 10.73 hours
# 2023-02-27: Daylight: 10.79 hours
# 2023-02-28: Daylight: 10.86 hours
# 2023-03-01: Daylight: 10.92 hours
# 2023-03-02: Daylight: 10.99 hours
# 2023-03-03: Daylight: 11.05 hours
# 2023-03-04: Daylight: 11.11 hours
# 2023-03-05: Daylight: 11.18 hours
# 2023-03-06: Daylight: 11.24 hours
# 2023-03-07: Daylight: 11.31 hours
# 2023-03-08: Daylight: 11.37 hours
# 2023-03-09: Daylight: 11.44 hours
# 2023-03-10: Daylight: 11.50 hours
# 2023-03-11: Daylight: 11.57 hours
# 2023-03-12: Daylight: 11.64 hours
# 2023-03-13: Daylight: 11.70 hours
# 2023-03-14: Daylight: 11.77 hours
# 2023-03-15: Daylight: 11.83 hours
# 2023-03-16: Daylight: 11.90 hours
# 2023-03-17: Daylight: 11.96 hours
# 2023-03-18: Daylight: 12.03 hours
# 2023-03-19: Daylight: 12.09 hours
# 2023-03-20: Daylight: 12.16 hours
# 2023-03-21: Daylight: 12.22 hours
# 2023-03-22: Daylight: 12.29 hours
# 2023-03-23: Daylight: 12.35 hours
# 2023-03-24: Daylight: 12.42 hours
# 2023-03-25: Daylight: 12.49 hours
# 2023-03-26: Daylight: 12.55 hours
# 2023-03-27: Daylight: 12.62 hours
# 2023-03-28: Daylight: 12.68 hours
# 2023-03-29: Daylight: 12.75 hours
# 2023-03-30: Daylight: 12.81 hours
# 2023-03-31: Daylight: 12.88 hours
# 2023-04-01: Daylight: 12.94 hours
# 2023-04-02: Daylight: 13.01 hours
# 2023-04-03: Daylight: 13.07 hours
# 2023-04-04: Daylight: 13.14 hours
# 2023-04-05: Daylight: 13.20 hours
# 2023-04-06: Daylight: 13.26 hours
# 2023-04-07: Daylight: 13.33 hours
# 2023-04-08: Daylight: 13.39 hours
# 2023-04-09: Daylight: 13.46 hours
# 2023-04-10: Daylight: 13.52 hours
# 2023-04-11: Daylight: 13.59 hours
# 2023-04-12: Daylight: 13.65 hours
# 2023-04-13: Daylight: 13.71 hours
# 2023-04-14: Daylight: 13.78 hours
# 2023-04-15: Daylight: 13.84 hours
# 2023-04-16: Daylight: 13.90 hours
# 2023-04-17: Daylight: 13.96 hours
# 2023-04-18: Daylight: 14.03 hours
# 2023-04-19: Daylight: 14.09 hours
# 2023-04-20: Daylight: 14.15 hours
# 2023-04-21: Daylight: 14.21 hours
# 2023-04-22: Daylight: 14.27 hours
# 2023-04-23: Daylight: 14.34 hours
# 2023-04-24: Daylight: 14.40 hours
# 2023-04-25: Daylight: 14.46 hours
# 2023-04-26: Daylight: 14.52 hours
# 2023-04-27: Daylight: 14.58 hours
# 2023-04-28: Daylight: 14.64 hours
# 2023-04-29: Daylight: 14.70 hours
# 2023-04-30: Daylight: 14.75 hours
# 2023-05-01: Daylight: 14.81 hours
# 2023-05-02: Daylight: 14.87 hours
# 2023-05-03: Daylight: 14.93 hours
# 2023-05-04: Daylight: 14.98 hours
# 2023-05-05: Daylight: 15.04 hours
# 2023-05-06: Daylight: 15.10 hours
# 2023-05-07: Daylight: 15.15 hours
# 2023-05-08: Daylight: 15.21 hours
# 2023-05-09: Daylight: 15.26 hours
# 2023-05-10: Daylight: 15.31 hours
# 2023-05-11: Daylight: 15.37 hours
# 2023-05-12: Daylight: 15.42 hours
# 2023-05-13: Daylight: 15.47 hours
# 2023-05-14: Daylight: 15.52 hours
# 2023-05-15: Daylight: 15.57 hours
# 2023-05-16: Daylight: 15.62 hours
# 2023-05-17: Daylight: 15.67 hours
# 2023-05-18: Daylight: 15.71 hours
# 2023-05-19: Daylight: 15.76 hours
# 2023-05-20: Daylight: 15.81 hours
# 2023-05-21: Daylight: 15.85 hours
# 2023-05-22: Daylight: 15.89 hours
# 2023-05-23: Daylight: 15.94 hours
# 2023-05-24: Daylight: 15.98 hours
# 2023-05-25: Daylight: 16.02 hours
# 2023-05-26: Daylight: 16.06 hours
# 2023-05-27: Daylight: 16.09 hours
# 2023-05-28: Daylight: 16.13 hours
# 2023-05-29: Daylight: 16.17 hours
# 2023-05-30: Daylight: 16.20 hours
# 2023-05-31: Daylight: 16.23 hours
# 2023-06-01: Daylight: 16.27 hours
# 2023-06-02: Daylight: 16.30 hours
# 2023-06-03: Daylight: 16.33 hours
# 2023-06-04: Daylight: 16.35 hours
# 2023-06-05: Daylight: 16.38 hours
# 2023-06-06: Daylight: 16.40 hours
# 2023-06-07: Daylight: 16.43 hours
# 2023-06-08: Daylight: 16.45 hours
# 2023-06-09: Daylight: 16.47 hours
# 2023-06-10: Daylight: 16.49 hours
# 2023-06-11: Daylight: 16.51 hours
# 2023-06-12: Daylight: 16.52 hours
# 2023-06-13: Daylight: 16.54 hours
# 2023-06-14: Daylight: 16.55 hours
# 2023-06-15: Daylight: 16.56 hours
# 2023-06-16: Daylight: 16.57 hours
# 2023-06-17: Daylight: 16.58 hours
# 2023-06-18: Daylight: 16.58 hours
# 2023-06-19: Daylight: 16.59 hours
# 2023-06-20: Daylight: 16.59 hours
# 2023-06-21: Daylight: 16.59 hours
# 2023-06-22: Daylight: 16.59 hours
# 2023-06-23: Daylight: 16.59 hours
# 2023-06-24: Daylight: 16.58 hours
# 2023-06-25: Daylight: 16.58 hours
# 2023-06-26: Daylight: 16.57 hours
# 2023-06-27: Daylight: 16.56 hours
# 2023-06-28: Daylight: 16.55 hours
# 2023-06-29: Daylight: 16.54 hours
# 2023-06-30: Daylight: 16.53 hours
# 2023-07-01: Daylight: 16.51 hours
# 2023-07-02: Daylight: 16.49 hours
# 2023-07-03: Daylight: 16.48 hours
# 2023-07-04: Daylight: 16.46 hours
# 2023-07-05: Daylight: 16.44 hours
# 2023-07-06: Daylight: 16.41 hours
# 2023-07-07: Daylight: 16.39 hours
# 2023-07-08: Daylight: 16.36 hours
# 2023-07-09: Daylight: 16.34 hours
# 2023-07-10: Daylight: 16.31 hours
# 2023-07-11: Daylight: 16.28 hours
# 2023-07-12: Daylight: 16.25 hours
# 2023-07-13: Daylight: 16.21 hours
# 2023-07-14: Daylight: 16.18 hours
# 2023-07-15: Daylight: 16.14 hours
# 2023-07-16: Daylight: 16.11 hours
# 2023-07-17: Daylight: 16.07 hours
# 2023-07-18: Daylight: 16.03 hours
# 2023-07-19: Daylight: 15.99 hours
# 2023-07-20: Daylight: 15.95 hours
# 2023-07-21: Daylight: 15.91 hours
# 2023-07-22: Daylight: 15.87 hours
# 2023-07-23: Daylight: 15.82 hours
# 2023-07-24: Daylight: 15.78 hours
# 2023-07-25: Daylight: 15.73 hours
# 2023-07-26: Daylight: 15.69 hours
# 2023-07-27: Daylight: 15.64 hours
# 2023-07-28: Daylight: 15.59 hours
# 2023-07-29: Daylight: 15.54 hours
# 2023-07-30: Daylight: 15.49 hours
# 2023-07-31: Daylight: 15.44 hours
# 2023-08-01: Daylight: 15.39 hours
# 2023-08-02: Daylight: 15.34 hours
# 2023-08-03: Daylight: 15.29 hours
# 2023-08-04: Daylight: 15.23 hours
# 2023-08-05: Daylight: 15.18 hours
# 2023-08-06: Daylight: 15.13 hours
# 2023-08-07: Daylight: 15.07 hours
# 2023-08-08: Daylight: 15.02 hours
# 2023-08-09: Daylight: 14.96 hours
# 2023-08-10: Daylight: 14.90 hours
# 2023-08-11: Daylight: 14.85 hours
# 2023-08-12: Daylight: 14.79 hours
# 2023-08-13: Daylight: 14.73 hours
# 2023-08-14: Daylight: 14.67 hours
# 2023-08-15: Daylight: 14.62 hours
# 2023-08-16: Daylight: 14.56 hours
# 2023-08-17: Daylight: 14.50 hours
# 2023-08-18: Daylight: 14.44 hours
# 2023-08-19: Daylight: 14.38 hours
# 2023-08-20: Daylight: 14.32 hours
# 2023-08-21: Daylight: 14.26 hours
# 2023-08-22: Daylight: 14.20 hours
# 2023-08-23: Daylight: 14.14 hours
# 2023-08-24: Daylight: 14.08 hours
# 2023-08-25: Daylight: 14.01 hours
# 2023-08-26: Daylight: 13.95 hours
# 2023-08-27: Daylight: 13.89 hours
# 2023-08-28: Daylight: 13.83 hours
# 2023-08-29: Daylight: 13.77 hours
# 2023-08-30: Daylight: 13.70 hours
# 2023-08-31: Daylight: 13.64 hours
# 2023-09-01: Daylight: 13.58 hours
# 2023-09-02: Daylight: 13.52 hours
# 2023-09-03: Daylight: 13.45 hours
# 2023-09-04: Daylight: 13.39 hours
# 2023-09-05: Daylight: 13.33 hours
# 2023-09-06: Daylight: 13.26 hours
# 2023-09-07: Daylight: 13.20 hours
# 2023-09-08: Daylight: 13.14 hours
# 2023-09-09: Daylight: 13.07 hours
# 2023-09-10: Daylight: 13.01 hours
# 2023-09-11: Daylight: 12.94 hours
# 2023-09-12: Daylight: 12.88 hours
# 2023-09-13: Daylight: 12.82 hours
# 2023-09-14: Daylight: 12.75 hours
# 2023-09-15: Daylight: 12.69 hours
# 2023-09-16: Daylight: 12.62 hours
# 2023-09-17: Daylight: 12.56 hours
# 2023-09-18: Daylight: 12.50 hours
# 2023-09-19: Daylight: 12.43 hours
# 2023-09-20: Daylight: 12.37 hours
# 2023-09-21: Daylight: 12.30 hours
# 2023-09-22: Daylight: 12.24 hours
# 2023-09-23: Daylight: 12.17 hours
# 2023-09-24: Daylight: 12.11 hours
# 2023-09-25: Daylight: 12.04 hours
# 2023-09-26: Daylight: 11.98 hours
# 2023-09-27: Daylight: 11.92 hours
# 2023-09-28: Daylight: 11.85 hours
# 2023-09-29: Daylight: 11.79 hours
# 2023-09-30: Daylight: 11.72 hours
# 2023-10-01: Daylight: 11.66 hours
# 2023-10-02: Daylight: 11.59 hours
# 2023-10-03: Daylight: 11.53 hours
# 2023-10-04: Daylight: 11.47 hours
# 2023-10-05: Daylight: 11.40 hours
# 2023-10-06: Daylight: 11.34 hours
# 2023-10-07: Daylight: 11.27 hours
# 2023-10-08: Daylight: 11.21 hours
# 2023-10-09: Daylight: 11.15 hours
# 2023-10-10: Daylight: 11.08 hours
# 2023-10-11: Daylight: 11.02 hours
# 2023-10-12: Daylight: 10.95 hours
# 2023-10-13: Daylight: 10.89 hours
# 2023-10-14: Daylight: 10.83 hours
# 2023-10-15: Daylight: 10.76 hours
# 2023-10-16: Daylight: 10.70 hours
# 2023-10-17: Daylight: 10.64 hours
# 2023-10-18: Daylight: 10.57 hours
# 2023-10-19: Daylight: 10.51 hours
# 2023-10-20: Daylight: 10.45 hours
# 2023-10-21: Daylight: 10.39 hours
# 2023-10-22: Daylight: 10.33 hours
# 2023-10-23: Daylight: 10.26 hours
# 2023-10-24: Daylight: 10.20 hours
# 2023-10-25: Daylight: 10.14 hours
# 2023-10-26: Daylight: 10.08 hours
# 2023-10-27: Daylight: 10.02 hours
# 2023-10-28: Daylight: 9.96 hours
# 2023-10-29: Daylight: 9.90 hours
# 2023-10-30: Daylight: 9.84 hours
# 2023-10-31: Daylight: 9.78 hours
# 2023-11-01: Daylight: 9.72 hours
# 2023-11-02: Daylight: 9.66 hours
# 2023-11-03: Daylight: 9.60 hours
# 2023-11-04: Daylight: 9.55 hours
# 2023-11-05: Daylight: 9.49 hours
# 2023-11-06: Daylight: 9.43 hours
# 2023-11-07: Daylight: 9.38 hours
# 2023-11-08: Daylight: 9.32 hours
# 2023-11-09: Daylight: 9.27 hours
# 2023-11-10: Daylight: 9.21 hours
# 2023-11-11: Daylight: 9.16 hours
# 2023-11-12: Daylight: 9.10 hours
# 2023-11-13: Daylight: 9.05 hours
# 2023-11-14: Daylight: 9.00 hours
# 2023-11-15: Daylight: 8.95 hours

# %%
# Convert daylight_hours_dict to a DataFrame for easier manipulation
daylight_df = pd.DataFrame.from_dict(daylight_hours_dict, orient='index', columns=['daylight']) 
daylight_df
# Out:
#             daylight
# 2018-12-24  7.906935
# 2018-12-25  7.912347
# 2018-12-26  7.919527
# 2018-12-27  7.928466
# 2018-12-28  7.939154
# ...              ...
# 2023-11-11  9.157498
# 2023-11-12  9.104315
# 2023-11-13  9.051822
# 2023-11-14  9.000053
# 2023-11-15  8.949039
#
# [1788 rows x 1 columns]

# %%
df = create_features(df)
df = add_lags(df)
df = pd.merge(df, daylight_df, left_on='date', right_index=True)
df['isHoliday'] = 0
# Mark holidays as 1
df.loc[df['date'].isin(holidays['date']), 'isHoliday'] = 1

FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year',
            'lag1','lag2', 'lag3', 'daylight', 'isHoliday']                                              
TARGET = 'gesamt'

X = df[FEATURES]
y = df[TARGET]

# %% [markdown]
# Find best model

# %% [markdown]
# Time Series Cross Validation

# %%
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
tss = TimeSeriesSplit(n_splits=10, test_size=24*30*1)  # gap: between training and test split (here 24 hours)
df = df.sort_index()

# %%
fig, axs = plt.subplots(10, 1, figsize=(15,15), sharex=True)

fold = 0

for train_idx, val_idx in tss.split(df):
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]
    train['gesamt'].plot(ax=axs[fold],
                         label='Training Set',
                         title=f'Data Train/Test Split Fold {fold}')
    test['gesamt'].plot(ax=axs[fold],
                         label='Test Set')
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold +=1
plt.show()

# %%
# from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

# tss = TimeSeriesSplit(n_splits=4, test_size=24*365*1, gap=24)
# df = df.sort_index()


# fold = 0
# preds = []
# scores = []
# for train_idx, val_idx in tss.split(df):
#     train = df.iloc[train_idx]
#     test = df.iloc[val_idx]

#     train = create_features(train)
#     test = create_features(test)

#     FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month','year',
#                 'lag1','lag2','lag3', 'daylight']
#     TARGET = 'gesamt'

#     X_train = train[FEATURES]
#     y_train = train[TARGET]

#     X_test = test[FEATURES]
#     y_test = test[TARGET]

#     reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
#                            n_estimators=1000,
#                            early_stopping_rounds=50,
#                            objective = 'reg:quantileerror', 
#                            quantile_alpha = alpha,
#                            max_depth=3,
#                            learning_rate=0.01)
    
#     reg.fit(X_train, y_train,
#             eval_set=[(X_train, y_train), (X_test, y_test)],
#             verbose=100)

#     y_pred = reg.predict(X_test)
#     preds.append(y_pred)
#     # score = np.sqrt(mean_squared_error(y_test, y_pred)) # hier quantile score
#     # scores.append(score)
# Out:
# [0]	validation_0-quantile:29.64018	validation_1-quantile:28.94838
# [100]	validation_0-quantile:9.67429	validation_1-quantile:8.99590
# [200]	validation_0-quantile:3.48537	validation_1-quantile:3.17245
# [300]	validation_0-quantile:1.70098	validation_1-quantile:1.70003
# [400]	validation_0-quantile:1.03488	validation_1-quantile:1.21122
# [500]	validation_0-quantile:0.77175	validation_1-quantile:1.05983
# [600]	validation_0-quantile:0.64870	validation_1-quantile:0.98844
# [700]	validation_0-quantile:0.58311	validation_1-quantile:0.96741
# [800]	validation_0-quantile:0.54610	validation_1-quantile:0.95896
# [834]	validation_0-quantile:0.53525	validation_1-quantile:0.95965
# [0]	validation_0-quantile:28.65860	validation_1-quantile:29.32569
# [100]	validation_0-quantile:8.91700	validation_1-quantile:9.53573
# [200]	validation_0-quantile:3.14838	validation_1-quantile:3.49466
# [300]	validation_0-quantile:1.55018	validation_1-quantile:1.70378
# [400]	validation_0-quantile:1.04187	validation_1-quantile:1.08083
# [500]	validation_0-quantile:0.84243	validation_1-quantile:0.84120
# [600]	validation_0-quantile:0.75609	validation_1-quantile:0.73658
# [700]	validation_0-quantile:0.70645	validation_1-quantile:0.68512
# [800]	validation_0-quantile:0.67952	validation_1-quantile:0.67024
# [900]	validation_0-quantile:0.66065	validation_1-quantile:0.66220
# [999]	validation_0-quantile:0.64580	validation_1-quantile:0.65389
# [0]	validation_0-quantile:27.86413	validation_1-quantile:30.15316
# [100]	validation_0-quantile:8.07288	validation_1-quantile:10.19329
# [200]	validation_0-quantile:2.72894	validation_1-quantile:3.82895
# [300]	validation_0-quantile:1.38067	validation_1-quantile:1.86079
# [400]	validation_0-quantile:0.96852	validation_1-quantile:1.13399
# [500]	validation_0-quantile:0.82272	validation_1-quantile:0.85167
# [600]	validation_0-quantile:0.75720	validation_1-quantile:0.72898
# [700]	validation_0-quantile:0.72402	validation_1-quantile:0.67228
# [800]	validation_0-quantile:0.70001	validation_1-quantile:0.63612
# [900]	validation_0-quantile:0.68005	validation_1-quantile:0.61526
# [999]	validation_0-quantile:0.66370	validation_1-quantile:0.60758
# [0]	validation_0-quantile:27.52391	validation_1-quantile:27.44581
# [100]	validation_0-quantile:7.78914	validation_1-quantile:7.70118
# [200]	validation_0-quantile:2.53940	validation_1-quantile:2.33760
# [300]	validation_0-quantile:1.25857	validation_1-quantile:1.07667
# [400]	validation_0-quantile:0.88547	validation_1-quantile:0.76479
# [500]	validation_0-quantile:0.76219	validation_1-quantile:0.69776
# [593]	validation_0-quantile:0.71317	validation_1-quantile:0.69367

# %% [markdown]
# Hyperparameter tuning

# %%
# df = create_features(df)
# df = add_lags(df)
# df = pd.merge(df, daylight_df, left_on='date', right_index=True)

# FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year',
#             'lag1','lag2', 'lag3', 'daylight']                                              
# TARGET = 'gesamt'

# X = df[FEATURES]
# y = df[TARGET]

# %%
# # Hyperparameter tuning 
# from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

# # Use TimeSeriesSplit for cross-validation
# # tss = TimeSeriesSplit(n_splits=4, test_size=24*365*1) # 10 splits, Test set 5 Tage
# # df = df.sort_index()

# # Define the parameter grid to search
# # more paramters?
# param_grid = {
#     'n_estimators': [100, 250, 500, 750, 1000], # nbr trees
#     'max_depth': [1, 3, 5],
#     'learning_rate': [0.01, 0.05, 0.1]#,
#     #'early_stopping_rounds': [10, 50]
# }

# model = xgb.XGBRegressor(objective='reg:squarederror', booster = 'gbtree')

# %%
# TimeSeriesSplit for cross-validation
# tscv = TimeSeriesSplit(n_splits=50, test_size=24*7*4)

# %%
# fig, axs = plt.subplots(50, 1, figsize=(15,15), sharex=True)

# fold = 0

# for train_idx, val_idx in tscv.split(df):
#     train = df.iloc[train_idx]
#     test = df.iloc[val_idx]
#     train['gesamt'].plot(ax=axs[fold],
#                          label='Training Set',
#                          title=f'Data Train/Test Split Fold {fold}')
#     test['gesamt'].plot(ax=axs[fold],
#                          label='Test Set')
#     axs[fold].axvline(test.index.min(), color='black', ls='--')
#     fold +=1
# plt.show()

# %%
# # make a GridSearchCV object
# GS = GridSearchCV(estimator=model,
#                   param_grid=param_grid,
#                   scoring=["r2", "neg_root_mean_squared_error"],
#                   refit = "r2", 
#                   cv = tscv
#                   #verbose = 4 # how much info to print
#                   )

# %%
# GS.fit(X, y)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=50, test_size=672),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, imp...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [1, 3, 5],
#                          'n_estimators': [100, 250, 500, 750, 1000]},
#              refit='r2', scoring=['r2', 'neg_root_mean_squared_error'])

# %%
# print(GS.best_estimator_)
# print(GS.best_params_)
# print(GS.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(GS.best_estimator_)
#       2 print(GS.best_params_)
#       3 print(GS.best_score_)
#
# NameError: name 'GS' is not defined

# %%
# gs_results = pd.DataFrame(GS.cv_results_)
# gs_results = gs_results.sort_values("rank_test_r2")
# gs_results.to_csv("cv_results.csv")

# %% [markdown]
# Tune Hyperparams for quantile regression

# %%
# Hyperparameter tuning 
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

# Use TimeSeriesSplit for cross-validation
tss = TimeSeriesSplit(n_splits=50, test_size=24*4) # 
# df = df.sort_index()

# Define the parameter grid to search
# more paramters?
param_grid = {
    'n_estimators': [200, 400, 600, 800 ], # nbr trees
    'max_depth': [1, 3, 5],
    'learning_rate': [0.01, 0.05, 0.1]#,
    #'early_stopping_rounds': [10, 50]
}

model_q1 = xgb.XGBRegressor(objective='reg:quantileerror', quantile_alpha = 0.025,  booster = 'gbtree')
model_q2 = xgb.XGBRegressor(objective='reg:quantileerror', quantile_alpha = 0.25,  booster = 'gbtree')
model_q3 = xgb.XGBRegressor(objective='reg:quantileerror', quantile_alpha = 0.5,  booster = 'gbtree')
model_q4 = xgb.XGBRegressor(objective='reg:quantileerror', quantile_alpha = 0.75,  booster = 'gbtree')
model_q5 = xgb.XGBRegressor(objective='reg:quantileerror', quantile_alpha = 0.9755,  booster = 'gbtree')
# TimeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=5, test_size=24*30)

# %%
# Define the pinball loss function for quantile regression
def mqloss(y_true, y_pred, alpha):  
  if (alpha > 0) and (alpha < 1):
    residual = y_true - y_pred 
    return np.mean(-2* residual * (alpha - (residual<0)))
  else:
    return np.nan

# Define the scorer using the pinball loss function
mqloss_scorer_q1 = make_scorer(mqloss, alpha=0.025)
mqloss_scorer_q2 = make_scorer(mqloss, alpha=0.25)
mqloss_scorer_q3 = make_scorer(mqloss, alpha=0.5)
mqloss_scorer_q4 = make_scorer(mqloss, alpha=0.75)
mqloss_scorer_q5 = make_scorer(mqloss, alpha=0.975)

# %%
gs_q1 = GridSearchCV(estimator=model_q1, param_grid=param_grid, scoring=mqloss_scorer_q1, cv=tss)
gs_q2 = GridSearchCV(estimator=model_q2, param_grid=param_grid, scoring=mqloss_scorer_q2, cv=tss)
gs_q3 = GridSearchCV(estimator=model_q3, param_grid=param_grid, scoring=mqloss_scorer_q3, cv=tss)
gs_q4 = GridSearchCV(estimator=model_q4, param_grid=param_grid, scoring=mqloss_scorer_q4, cv=tss)
gs_q5 = GridSearchCV(estimator=model_q5, param_grid=param_grid, scoring=mqloss_scorer_q5, cv=tss)


# to check if  scorer works correctly
# gs_q3 = GridSearchCV(
#         estimator=model_q3,
#         param_grid=param_grid,
#         scoring= 'neg_mean_absolute_error',
#         cv=tss  # 5-fold cross-validation
#     )
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=4, test_size=720),
#              estimator=XGBRegressor(base_score=None, booster='gbtree',
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None,...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     objective='reg:quantileerror', ...),
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [1, 3, 5],
#                          'n_estimators': [100, 200, 400]},
#              scoring=make_scorer(mqloss, response_method='predict', alpha=0.5))

# %%
gs_q1.fit(X, y)

# %%
gs_q2.fit(X, y)

# %%
gs_q3.fit(X, y)

# %%
gs_q4.fit(X, y)

# %%
gs_q5.fit(X, y)

# %%
print(gs_q3.best_estimator_)
print(gs_q3.best_params_)
print(gs_q3.best_score_)
# Out:
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=400, n_jobs=None,
#              num_parallel_tree=None, objective='reg:quantileerror', ...)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 400}
# -1.4023176238271926

# %%
gs_q3_results = pd.DataFrame(gs_q3.cv_results_)
gs_q3_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        1.349732      0.173054         0.012634        0.014498
# 1        3.027976      0.058707         0.008589        0.001470
# 2        6.548887      0.135219         0.006351        0.002499
# 3        1.178357      0.034092         0.004995        0.003353
# 4        2.171306      0.056500         0.007659        0.002623
# 5        4.633065      0.117446         0.009985        0.000627
# 6        1.315830      0.034885         0.006538        0.003861
# 7        2.287817      0.051379         0.006930        0.003143
# 8        4.709578      0.152530         0.008075        0.004063
# 9        1.744561      0.032442         0.005871        0.002999
# 10       3.555865      0.075891         0.007579        0.002953
# 11       6.989324      0.152142         0.004681        0.003929
# 12       1.355595      0.047778         0.008033        0.003471
# 13       2.677611      0.102493         0.005285        0.004352
# 14       5.111474      0.179407         0.008223        0.003186
# 15       1.268045      0.023799         0.009503        0.002803
# 16       2.557005      0.092429         0.011075        0.002490
# 17       5.223484      0.250982         0.009438        0.001086
# 18       1.823770      0.054820         0.008885        0.002222
# 19       3.598474      0.079288         0.004159        0.002476
# 20       7.050342      0.589628         0.006915        0.006677
# 21       1.728836      0.161801         0.009778        0.001704
# 22       3.647622      0.273716         0.008187        0.003271
# 23       5.080406      0.125651         0.007542        0.003296
# 24       1.340357      0.047032         0.006926        0.003368
# 25       2.640858      0.051386         0.005305        0.003305
# 26       5.397715      0.078354         0.009429        0.001085
#
#    param_learning_rate param_max_depth param_n_estimators  \
# 0                 0.01               1                100
# 1                 0.01               1                200
# 2                 0.01               1                400
# 3                 0.01               3                100
# 4                 0.01               3                200
# 5                 0.01               3                400
# 6                 0.01               5                100
# 7                 0.01               5                200
# 8                 0.01               5                400
# 9                 0.05               1                100
# 10                0.05               1                200
# 11                0.05               1                400
# 12                0.05               3                100
# 13                0.05               3                200
# 14                0.05               3                400
# 15                0.05               5                100
# 16                0.05               5                200
# 17                0.05               5                400
# 18                 0.1               1                100
# 19                 0.1               1                200
# 20                 0.1               1                400
# 21                 0.1               3                100
# 22                 0.1               3                200
# 23                 0.1               3                400
# 24                 0.1               5                100
# 25                 0.1               5                200
# 26                 0.1               5                400
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.01, 'max_depth': 1, 'n_est...          -5.141696
# 1   {'learning_rate': 0.01, 'max_depth': 1, 'n_est...          -3.744307
# 2   {'learning_rate': 0.01, 'max_depth': 1, 'n_est...          -2.421685
# 3   {'learning_rate': 0.01, 'max_depth': 3, 'n_est...          -4.303648
# 4   {'learning_rate': 0.01, 'max_depth': 3, 'n_est...          -2.461029
# 5   {'learning_rate': 0.01, 'max_depth': 3, 'n_est...          -1.443865
# 6   {'learning_rate': 0.01, 'max_depth': 5, 'n_est...          -4.254906
# 7   {'learning_rate': 0.01, 'max_depth': 5, 'n_est...          -2.300769
# 8   {'learning_rate': 0.01, 'max_depth': 5, 'n_est...          -1.352695
# 9   {'learning_rate': 0.05, 'max_depth': 1, 'n_est...          -2.040981
# 10  {'learning_rate': 0.05, 'max_depth': 1, 'n_est...          -1.473558
# 11  {'learning_rate': 0.05, 'max_depth': 1, 'n_est...          -1.157104
# 12  {'learning_rate': 0.05, 'max_depth': 3, 'n_est...          -1.244849
# 13  {'learning_rate': 0.05, 'max_depth': 3, 'n_est...          -1.063520
# 14  {'learning_rate': 0.05, 'max_depth': 3, 'n_est...          -1.009501
# 15  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...          -1.193132
# 16  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...          -1.139595
# 17  {'learning_rate': 0.05, 'max_depth': 5, 'n_est...          -1.093508
# 18  {'learning_rate': 0.1, 'max_depth': 1, 'n_esti...          -1.462846
# 19  {'learning_rate': 0.1, 'max_depth': 1, 'n_esti...          -1.160946
# 20  {'learning_rate': 0.1, 'max_depth': 1, 'n_esti...          -1.073177
# 21  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...          -1.069515
# 22  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...          -1.022336
# 23  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...          -1.013933
# 24  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...          -1.169466
# 25  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...          -1.223633
# 26  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...          -1.239429
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           -4.758215          -5.141352          -4.151809        -4.798268
# 1           -3.396629          -3.900151          -2.913625        -3.488678
# 2           -2.086058          -2.760198          -2.295504        -2.390861
# 3           -3.928361          -4.246068          -3.357977        -3.959014
# 4           -2.122000          -2.689537          -2.324982        -2.399387
# 5           -1.219060          -1.982564          -2.084298        -1.682447
# 6           -3.849316          -4.089618          -3.109875        -3.825929
# 7           -1.962881          -2.468301          -2.098402        -2.207588
# 8           -1.148356          -1.814729          -1.982020        -1.574450
# 9           -1.747758          -2.515331          -2.222547        -2.131654
# 10          -1.252931          -2.116407          -2.098974        -1.735467
# 11          -1.161108          -2.000275          -2.054523        -1.593253
# 12          -1.135881          -1.894700          -2.002974        -1.569601
# 13          -1.127775          -1.907112          -1.970978        -1.517347
# 14          -1.113327          -1.951287          -1.802860        -1.469244
# 15          -1.069600          -1.740572          -1.903637        -1.476735
# 16          -1.021994          -1.789876          -1.815950        -1.441854
# 17          -0.970906          -1.844205          -1.700652        -1.402318
# 18          -1.262348          -2.129847          -2.125953        -1.745249
# 19          -1.177051          -2.023818          -2.085459        -1.611818
# 20          -1.147320          -1.973011          -2.046617        -1.560031
# 21          -1.125309          -1.892511          -1.960529        -1.511966
# 22          -1.074353          -1.895261          -1.814561        -1.451628
# 23          -1.057985          -1.893026          -1.688396        -1.413335
# 24          -1.064798          -1.913674          -1.819194        -1.491783
# 25          -1.019323          -1.970904          -1.705143        -1.479751
# 26          -1.019742          -1.978025          -1.497705        -1.433726
#
#     std_test_score  rank_test_score
# 0         0.404711               27
# 1         0.378753               24
# 2         0.244621               22
# 3         0.375286               26
# 4         0.206438               23
# 5         0.361664               17
# 6         0.437845               25
# 7         0.192650               21
# 8         0.337112               14
# 9         0.278867               20
# 10        0.380358               18
# 11        0.434572               15
# 12        0.383105               13
# 13        0.422913               11
# 14        0.412827                6
# 15        0.352861                7
# 16        0.363562                4
# 17        0.376081                1
# 18        0.389165               19
# 19        0.443393               16
# 20        0.451297               12
# 21        0.415719               10
# 22        0.404709                5
# 23        0.384564                2
# 24        0.377953                9
# 25        0.377367                8
# 26        0.356892                3

# %%
gs_q3_results = gs_q3_results.sort_values("rank_test_score")
gs_q3_results.to_csv("gs_q3_alt_results.csv")

# %%
y_gercek = np.array([1, 4, 10])
y_sahte = np.array([2, 3, 14])

mqloss(y_true = y_gercek, y_pred = y_sahte, alpha = 0.25)
# Out:
# -2.6666666666666665
